# %%
# !pip install timm
# !pip install matplotlib

# %%
RUN_TRAIN = True  # bfloat16 or float32 recommended
RUN_VALID = False
RUN_TEST  = False

import torch
#if not torch.cuda.is_available() or torch.cuda.device_count() < 2:
#    raise RuntimeError("Requires >= 2 GPUs with CUDA enabled.")

try:
    import monai
except:
    # !pip install --no-deps monai -q
# Out:
# 2025-07-01 10:51:01.822753: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-01 10:51:01.867947: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-01 10:51:01.867970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-01 10:51:01.869842: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-01 10:51:01.878353: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-01 10:51:02.820583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Caformer Improved Notebook
#
# This is the final notebook I will release in this competition. I recommend reading the previous notebooks, as many components are reused.
#
# 1. [HGNet-V2 - Starter](https://www.kaggle.com/code/brendanartley/hgnet-v2-starter)
# 2. [ConvNeXt - Full Resolution Baseline](https://www.kaggle.com/code/brendanartley/convnext-full-resolution-baseline)
# 3. [CAFormer - Full Resolution Improved](https://www.kaggle.com/code/brendanartley/caformer-full-resolution-improved)
#
#
# This notebook features the strongest model I have found so far. A modified CAFormer encoder combined with an improved decoder (pixel shuffle, intermediate convolutions, and SCSE blocks).
#
# Like previous notebooks, I provide a pre-trained model checkpoint (trained for 150 epochs) which achieved a validation MAE of ~24.

# %%
# %%writefile _cfg.py

from types import SimpleNamespace
import torch

cfg= SimpleNamespace()
cfg.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cfg.local_rank = 0
cfg.seed = 123
cfg.subsample = None

cfg.backbone = "caformer_b36.sail_in22k_ft_in1k"
cfg.ema = True
cfg.ema_decay = 0.99

cfg.epochs = 200
cfg.batch_size = 16
cfg.batch_size_val = 16

cfg.early_stopping = {"patience": 200, "streak": 0}
cfg.logging_steps = 100
# Out:
# Overwriting _cfg.py

# %% [markdown]
# # Scheduler
#
# I have removed the training loop from this notebook, though it is the same as previous notebooks.
#
# The only difference was the use of a custom learning rate scheduler. The scheduler uses a constant learning rate followed by a cosine annealing learning rate. It seems that a learning rate of 1e-4 works well at the beggining, but a lower learning rate is required to achieve lower training and validation MAE.

# %%
import math

from torch.optim.lr_scheduler import _LRScheduler

class ConstantCosineLR(_LRScheduler):
    """
    Constant learning rate followed by CosineAnnealing.
    """
    def __init__(
        self,
        optimizer,
        total_steps,
        pct_cosine,
        last_epoch=-1,
        ):
        self.total_steps = total_steps
        self.milestone = int(total_steps * (1 - pct_cosine))
        self.cosine_steps = max(total_steps - self.milestone, 1)
        self.min_lr = 0
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        step = self.last_epoch + 1
        if step <= self.milestone:
            factor = 1.0
        else:
            s = step - self.milestone
            factor = 0.5 * (1 + math.cos(math.pi * s / self.cosine_steps))
        return [lr * factor for lr in self.base_lrs]

# %%
import torch
import matplotlib.pyplot as plt

# Dummy model
n_steps = 10_000
model = torch.nn.Linear(1, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=1.0)

# Scheduler
scheduler = ConstantCosineLR(optimizer, total_steps=n_steps, pct_cosine=0.5)

# Get LRs
arr = []
for _ in range(n_steps):
    scheduler.step()
    arr.append(optimizer.param_groups[0]['lr'])

plt.plot(arr)
plt.xlabel("Step")
plt.ylabel("LR")
plt.title("ConstantCosineLR")
plt.show()

# %% [markdown]
# ### Dataset
#
# Same as previous notebook.

# %%
# %%writefile _dataset.py

import os
import glob

import numpy as np
import pandas as pd
from tqdm import tqdm

import torch

class CustomDataset(torch.utils.data.Dataset):
    def __init__(
        self,
        cfg,
        mode = "train",
    ):
        self.cfg = cfg
        self.mode = mode

        self.data, self.labels, self.records = self.load_metadata()

    def load_metadata(self, ):

        # Select rows
        df= pd.read_csv("../input/openfwi-preprocessed-72x72/folds.csv")
        if self.cfg.subsample is not None:
            df= df.groupby(["dataset", "fold"]).head(self.cfg.subsample)

        if self.mode == "train":
            df= df[df["fold"] != 0]
        else:
            df= df[df["fold"] == 0]


        data = []
        labels = []
        records = []
        mmap_mode = "r"

        for idx, row in tqdm(df.iterrows(), total=len(df), disable=self.cfg.local_rank != 0):
            row= row.to_dict()

            # Hacky way to get exact file name
            # p1 = os.path.join("/home/OpenFWI_float32", row["data_fpath"])
            # p2 = os.path.join("/home/OpenFWI_float32", row["data_fpath"].split("/")[0], "*", row["data_fpath"].split("/")[-1])
            p1 = os.path.join("../input/open-wfi-1/openfwi_float16_1/", row["data_fpath"])
            p2 = os.path.join("../input/open-wfi-1/openfwi_float16_1/", row["data_fpath"].split("/")[0], "*", row["data_fpath"].split("/")[-1])
            p3 = os.path.join("../input/open-wfi-2/openfwi_float16_2/", row["data_fpath"])
            p4 = os.path.join("../input/open-wfi-2/openfwi_float16_2/", row["data_fpath"].split("/")[0], "*", row["data_fpath"].split("/")[-1])
            farr= glob.glob(p1) + glob.glob(p2) + glob.glob(p3) + glob.glob(p4)

            # Map to lbl fpath
            farr= farr[0]
            flbl= farr.replace('seis', 'vel').replace('data', 'model')

            # Load
            arr= np.load(farr, mmap_mode=mmap_mode)
            lbl= np.load(flbl, mmap_mode=mmap_mode)

            # Append
            data.append(arr)
            labels.append(lbl)
            records.append(row["dataset"])

        return data, labels, records

    def __getitem__(self, idx):
        row_idx= idx // 500
        col_idx= idx % 500

        d= self.records[row_idx]
        x= self.data[row_idx][col_idx, ...]
        y= self.labels[row_idx][col_idx, ...]

        # Augs
        if self.mode == "train":

            # Temporal flip
            if np.random.random() < 0.5:
                x= x[::-1, :, ::-1]
                y= y[..., ::-1]

        x= x.copy()
        y= y.copy()

        return x, y

    def __len__(self, ):
        return len(self.records) * 500
# Out:
# Overwriting _dataset.py

# %% [markdown]
# # Model
#
# This time we use the `CAFormer` backbone from timm. See more info on this backbone [here](https://huggingface.co/timm/caformer_b36.sail_in22k_ft_in1k) and the original paper [here](https://arxiv.org/abs/2210.13452).
#
#
# ### Encoder
#
# Like with Convnext, we modify the encoder so that the feature maps are aligned with the target output shape. I think there is room for improvement at the `nn.ReflectionPad2d` step. Currently, the model uses lots of padding here and I am afraid the detail in the shallowest feature map is lacking.
#
# ### Decoder
#
# The biggest changes in this notebook are to the decoder.
#
# First, we use PixelShuffle for upsampling. Pixelshuffle typically works well when fine detail is important, though it is more computatially expensive. Second, we add SCSE blocks. These are commonly used to increase decoder capacity with a minimal increase in parameter count and runtime. Finally, we add intermediate convolutions between the encoder output and decoder blocks. I beleive this trick was first introduced on Kaggle in the 3rd place solution of the Contrails Competition [here](https://www.kaggle.com/competitions/google-research-identify-contrails-redu), and also increases decoder capacity.

# %%
# %%writefile _model.py
from copy import deepcopy
from types import MethodType

import torch
import torch.nn as nn
import torch.nn.functional as F

import timm

from monai.networks.blocks import UpSample, SubpixelUpsample

####################
## EMA + Ensemble ##
####################

class ModelEMA(nn.Module):
    def __init__(self, model, decay=0.99, device=None):
        super().__init__()
        self.module = deepcopy(model)
        self.module.eval()
        self.decay = decay
        self.device = device
        if self.device is not None:
            self.module.to(device=device)

    def _update(self, model, update_fn):
        with torch.no_grad():
            for ema_v, model_v in zip(self.module.state_dict().values(), model.state_dict().values()):
                if self.device is not None:
                    model_v = model_v.to(device=self.device)
                ema_v.copy_(update_fn(ema_v, model_v))

    def update(self, model):
        self._update(model, update_fn=lambda e, m: self.decay * e + (1. - self.decay) * m)

    def set(self, model):
        self._update(model, update_fn=lambda e, m: m)


class EnsembleModel(nn.Module):
    def __init__(self, models):
        super().__init__()
        self.models = nn.ModuleList(models).eval()

    def forward(self, x):
        output = None

        for m in self.models:
            logits= m(x)

            if output is None:
                output = logits
            else:
                output += logits

        output /= len(self.models)
        return output


#############
## Decoder ##
#############

class ConvBnAct2d(nn.Module):
    def __init__(
        self,
        in_channels,
        out_channels,
        kernel_size,
        padding: int = 0,
        stride: int = 1,
        norm_layer: nn.Module = nn.Identity,
        act_layer: nn.Module = nn.ReLU,
    ):
        super().__init__()

        self.conv= nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size,
            stride=stride,
            padding=padding,
            bias=False,
        )
        self.norm = norm_layer(out_channels) if norm_layer != nn.Identity else nn.Identity()
        self.act= act_layer(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.norm(x)
        x = self.act(x)
        return x


class SCSEModule2d(nn.Module):
    def __init__(self, in_channels, reduction=16):
        super().__init__()
        self.cSE = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, in_channels // reduction, 1),
            nn.Tanh(),
            nn.Conv2d(in_channels // reduction, in_channels, 1),
            nn.Sigmoid(),
        )
        self.sSE = nn.Sequential(
            nn.Conv2d(in_channels, 1, 1),
            nn.Sigmoid(),
            )

    def forward(self, x):
        return x * self.cSE(x) + x * self.sSE(x)

class Attention2d(nn.Module):
    def __init__(self, name, **params):
        super().__init__()
        if name is None:
            self.attention = nn.Identity(**params)
        elif name == "scse":
            self.attention = SCSEModule2d(**params)
        else:
            raise ValueError("Attention {} is not implemented".format(name))

    def forward(self, x):
        return self.attention(x)

class DecoderBlock2d(nn.Module):
    def __init__(
        self,
        in_channels,
        skip_channels,
        out_channels,
        norm_layer: nn.Module = nn.Identity,
        attention_type: str = None,
        intermediate_conv: bool = False,
        upsample_mode: str = "deconv",
        scale_factor: int = 2,
    ):
        super().__init__()

        # Upsample block
        if upsample_mode == "pixelshuffle":
            self.upsample= SubpixelUpsample(
                spatial_dims= 2,
                in_channels= in_channels,
                scale_factor= scale_factor,
            )
        else:
            self.upsample = UpSample(
                spatial_dims= 2,
                in_channels= in_channels,
                out_channels= in_channels,
                scale_factor= scale_factor,
                mode= upsample_mode,
            )

        if intermediate_conv:
            k= 3
            c= skip_channels if skip_channels != 0 else in_channels
            self.intermediate_conv = nn.Sequential(
                ConvBnAct2d(c, c, k, k//2),
                ConvBnAct2d(c, c, k, k//2),
                )
        else:
            self.intermediate_conv= None

        self.attention1 = Attention2d(
            name= attention_type,
            in_channels= in_channels + skip_channels,
            )

        self.conv1 = ConvBnAct2d(
            in_channels + skip_channels,
            out_channels,
            kernel_size= 3,
            padding= 1,
            norm_layer= norm_layer,
        )

        self.conv2 = ConvBnAct2d(
            out_channels,
            out_channels,
            kernel_size= 3,
            padding= 1,
            norm_layer= norm_layer,
        )
        self.attention2 = Attention2d(
            name= attention_type,
            in_channels= out_channels,
            )

    def forward(self, x, skip=None):
        x = self.upsample(x)

        if self.intermediate_conv is not None:
            if skip is not None:
                skip = self.intermediate_conv(skip)
            else:
                x = self.intermediate_conv(x)

        if skip is not None:
            # print(x.shape, skip.shape)
            x = torch.cat([x, skip], dim=1)
            x = self.attention1(x)

        x = self.conv1(x)
        x = self.conv2(x)
        x = self.attention2(x)
        return x


class UnetDecoder2d(nn.Module):
    """
    Unet decoder.
    Source: https://arxiv.org/abs/1505.04597
    """
    def __init__(
        self,
        encoder_channels: tuple[int],
        skip_channels: tuple[int] = None,
        decoder_channels: tuple = (256, 128, 64, 32),
        scale_factors: tuple = (2,2,2,2),
        norm_layer: nn.Module = nn.Identity,
        attention_type: str = "scse",
        intermediate_conv: bool = True,
        upsample_mode: str = "pixelshuffle",
    ):
        super().__init__()

        if len(encoder_channels) == 4:
            decoder_channels= decoder_channels[1:]
        self.decoder_channels= decoder_channels

        if skip_channels is None:
            skip_channels= list(encoder_channels[1:]) + [0]

        # Build decoder blocks
        in_channels= [encoder_channels[0]] + list(decoder_channels[:-1])
        self.blocks = nn.ModuleList()

        for i, (ic, sc, dc) in enumerate(zip(in_channels, skip_channels, decoder_channels)):
            # print(i, ic, sc, dc)
            self.blocks.append(
                DecoderBlock2d(
                    ic, sc, dc,
                    norm_layer= norm_layer,
                    attention_type= attention_type,
                    intermediate_conv= intermediate_conv,
                    upsample_mode= upsample_mode,
                    scale_factor= scale_factors[i],
                    )
            )

    def forward(self, feats: list[torch.Tensor]):
        res= [feats[0]]
        feats= feats[1:]

        # Decoder blocks
        for i, b in enumerate(self.blocks):
            skip= feats[i] if i < len(feats) else None
            res.append(
                b(res[-1], skip=skip),
                )

        return res

class SegmentationHead2d(nn.Module):
    def __init__(
        self,
        in_channels,
        out_channels,
        scale_factor: tuple[int] = (2,2),
        kernel_size: int = 3,
        mode: str = "nontrainable",
    ):
        super().__init__()
        self.conv= nn.Conv2d(
            in_channels, out_channels, kernel_size= kernel_size,
            padding= kernel_size//2
        )
        self.upsample = UpSample(
            spatial_dims= 2,
            in_channels= out_channels,
            out_channels= out_channels,
            scale_factor= scale_factor,
            mode= mode,
        )

    def forward(self, x):
        x = self.conv(x)
        x = self.upsample(x)
        return x


#############
## Encoder ##
#############

class Net(nn.Module):
    def __init__(
        self,
        backbone: str,
        pretrained: bool = True,
    ):
        super().__init__()

        # Encoder
        self.backbone= timm.create_model(
            backbone,
            in_chans= 5,
            pretrained= pretrained,
            features_only= True,
            drop_path_rate=0.0,
            )
        ecs= [_["num_chs"] for _ in self.backbone.feature_info][::-1]

        # Decoder
        self.decoder= UnetDecoder2d(
            encoder_channels= ecs,
        )

        self.seg_head= SegmentationHead2d(
            in_channels= self.decoder.decoder_channels[-1],
            out_channels= 1,
            scale_factor= 1,
        )

        self._update_stem(backbone)

    def _update_stem(self, backbone):
        m = self.backbone

        m.stem.conv.stride=(4,1)
        m.stem.conv.padding=(0,4)
        m.stages_0.downsample = nn.AvgPool2d(kernel_size=(4,1), stride=(4,1))
        m.stem= nn.Sequential(
            nn.ReflectionPad2d((0,0,78,78)),
            m.stem,
        )

        pass


    def proc_flip(self, x_in):
        x_in= torch.flip(x_in, dims=[-3, -1])
        x= self.backbone(x_in)
        x= x[::-1]

        # Decoder
        x= self.decoder(x)
        x_seg= self.seg_head(x[-1])
        x_seg= x_seg[..., 1:-1, 1:-1]
        x_seg= torch.flip(x_seg, dims=[-1])
        x_seg= x_seg * 1500 + 3000
        return x_seg

    def forward(self, batch):
        x= batch

        # Encoder
        x_in = x
        x= self.backbone(x)
        # print([_.shape for _ in x])
        x= x[::-1]

        # Decoder
        x= self.decoder(x)
        # print([_.shape for _ in x])
        x_seg= self.seg_head(x[-1])
        x_seg= x_seg[..., 1:-1, 1:-1]
        x_seg= x_seg * 1500 + 3000

        if self.training:
            return x_seg
        else:
            p1 = self.proc_flip(x_in)
            x_seg = torch.mean(torch.stack([x_seg, p1]), dim=0)
            return x_seg
# Out:
# Overwriting _model.py

# %% [markdown]
# ### Utils
#
# Same as previous notebook.

# %%
# %%writefile _utils.py
import datetime

def format_time(elapsed):
    elapsed_rounded = int(round((elapsed)))
    return str(datetime.timedelta(seconds=elapsed_rounded))
# Out:
# Overwriting _utils.py

# %% [markdown]
# # training

# %%
# %%writefile _train.py

import os
import time
import random
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.amp import autocast
from torch.cuda.amp import GradScaler

import torch.distributed as dist
from torch.utils.data import DistributedSampler
from torch.nn.parallel import DistributedDataParallel

from _cfg import cfg
from _dataset import CustomDataset
from _model import ModelEMA, Net
from _utils import format_time

import math
from torch.optim.lr_scheduler import _LRScheduler

def set_seed(seed=1234):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def setup(rank, world_size):
    torch.cuda.set_device(rank)
    dist.init_process_group("nccl", rank=rank, world_size=world_size)
    return

def cleanup():
    dist.barrier()
    dist.destroy_process_group()
    return

def main(cfg):
    class ConstantCosineLR(_LRScheduler):
        """
        Constant learning rate followed by CosineAnnealing.
        """
        def __init__(
            self,
            optimizer,
            total_steps,
            pct_cosine,
            last_epoch=-1,
            ):
            self.total_steps = total_steps
            self.milestone = int(total_steps * (1 - pct_cosine))
            self.cosine_steps = max(total_steps - self.milestone, 1)
            self.min_lr = 0
            super().__init__(optimizer, last_epoch)
    
        def get_lr(self):
            step = self.last_epoch + 1
            if step <= self.milestone:
                factor = 1.0
            else:
                s = step - self.milestone
                factor = 0.5 * (1 + math.cos(math.pi * s / self.cosine_steps))
            return [lr * factor for lr in self.base_lrs]

    # ========== Datasets / Dataloaders ==========
    if cfg.local_rank == 0:
        print("="*25)
        print("Loading data..")
    train_ds = CustomDataset(cfg=cfg, mode="train")
    sampler= DistributedSampler(
        train_ds,
        num_replicas=cfg.world_size,
        rank=cfg.local_rank,
    )
    train_dl = torch.utils.data.DataLoader(
        train_ds,
        sampler= sampler,
        batch_size= cfg.batch_size,
        num_workers=max(1, os.cpu_count() // cfg.world_size - 4),
    )

    valid_ds = CustomDataset(cfg=cfg, mode="valid")
    sampler= DistributedSampler(
        valid_ds,
        num_replicas=cfg.world_size,
        rank=cfg.local_rank,
    )
    valid_dl = torch.utils.data.DataLoader(
        valid_ds,
        sampler= sampler,
        batch_size= cfg.batch_size_val,
        num_workers=max(1, os.cpu_count() // cfg.world_size - 4),
    )

    # ========== Model / Optim ==========
    #model = Net(backbone=cfg.backbone)

    model = Net(
        backbone=cfg.backbone,
        pretrained=False,
    )
    
    # state_dict= torch.load("/root/autodl-tmp/yale/exp009_former/pretrain/pretrain_caformer_24_07_seed3.pt", map_location=cfg.device, weights_only=True)
    # state_dict= {k.removeprefix("_orig_mod."):v for k,v in state_dict.items()} 
    # model.load_state_dict(state_dict)
    
    model= model.to(cfg.local_rank)

    if cfg.ema:
        if cfg.local_rank == 0:
            print("Initializing EMA model..")
        ema_model = ModelEMA(
            model,
            decay=cfg.ema_decay,
            device=cfg.local_rank,
        )
    else:
        ema_model = None
    model= DistributedDataParallel(
        model,
        device_ids=[cfg.local_rank],
        )

    criterion = nn.L1Loss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4) #Original 1e-3
    scaler = GradScaler()

    total_steps = cfg.epochs * len(train_dl)
    scheduler = ConstantCosineLR(
        optimizer,
        total_steps=total_steps,
        pct_cosine=0.9,  # or any value you choose (e.g., 0.3, 0.8)
    )


    # ========== Training ==========
    if cfg.local_rank == 0:
        print("="*25)
        print("Give me warp {}, Mr. Sulu.".format(cfg.world_size))
        print("="*25)

    best_loss= 1_000_000
    val_loss= 1_000_000

    for epoch in range(0, cfg.epochs+1):
        if epoch != 0:
            tstart= time.time()
            train_dl.sampler.set_epoch(epoch)

            # Train loop
            model.train()
            total_loss = []
            for i, (x, y) in enumerate(train_dl):
                x = x.to(cfg.local_rank)
                y = y.to(cfg.local_rank)

                with autocast(cfg.device.type):
                    logits = model(x)

                loss = criterion(logits, y)

                scaler.scale(loss).backward()
                scaler.unscale_(optimizer)

                torch.nn.utils.clip_grad_norm_(model.parameters(), 3.0)

                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()

                total_loss.append(loss.item())

                if ema_model is not None:
                    ema_model.update(model)

                if cfg.local_rank == 0 and (len(total_loss) >= cfg.logging_steps or i == 0):
                    train_loss = np.mean(total_loss)
                    total_loss = []
                    current_lr = optimizer.param_groups[0]["lr"]
                    print("Epoch {}:     Train MAE: {:.2f}     Val MAE: {:.2f}     LR: {}     Time: {}     Step: {}/{}".format(
                        epoch,
                        train_loss,
                        val_loss,
                        current_lr,
                        format_time(time.time() - tstart),
                        i+1,
                        len(train_dl)+1,
                    ))

                scheduler.step()

        # ========== Valid ==========
        model.eval()
        val_logits = []
        val_targets = []
        with torch.no_grad():
            for x, y in tqdm(valid_dl, disable=cfg.local_rank != 0):
                x = x.to(cfg.local_rank)
                y = y.to(cfg.local_rank)

                with autocast(cfg.device.type):
                    if ema_model is not None:
                        out = ema_model.module(x)
                    else:
                        out = model(x)

                val_logits.append(out.cpu())
                val_targets.append(y.cpu())

            val_logits= torch.cat(val_logits, dim=0)
            val_targets= torch.cat(val_targets, dim=0)

            loss = criterion(val_logits, val_targets).item()

        # Gather loss
        v = torch.tensor([loss], device=cfg.local_rank)
        torch.distributed.all_reduce(v, op=dist.ReduceOp.SUM)
        val_loss = (v[0] / cfg.world_size).item()

        # ========== Weights / Early stopping ==========
        stop_train = torch.tensor([0], device=cfg.local_rank)
        if cfg.local_rank == 0:
            es= cfg.early_stopping
            print("Saved weights latest..")
            if ema_model is not None:
                torch.save(ema_model.module.state_dict(), f'latest/best_model_{cfg.seed}.pt')
            else:
                torch.save(model.state_dict(), f'latest/best_model_{cfg.seed}.pt')
            
            if val_loss < best_loss:
                print("New best: {:.2f} -> {:.2f}".format(best_loss, val_loss))
                print("Saved weights..")
                best_loss = val_loss
                if ema_model is not None:
                    torch.save(ema_model.module.state_dict(), f'best_model_{cfg.seed}.pt')
                else:
                    torch.save(model.state_dict(), f'best_model_{cfg.seed}.pt')

                es["streak"] = 0
            else:
                es= cfg.early_stopping
                es["streak"] += 1
                if es["streak"] > es["patience"]:
                    print("Ending training (early_stopping).")
                    stop_train = torch.tensor([1], device=cfg.local_rank)

        # Exits training on all ranks
        dist.broadcast(stop_train, src=0)
        if stop_train.item() == 1:
            return

    return



if __name__ == "__main__":

    # GPU Specs
    rank = int(os.environ["RANK"])
    world_size = int(os.environ["WORLD_SIZE"])
    _, total = torch.cuda.mem_get_info(device=rank)

    # Init
    setup(rank, world_size)
    time.sleep(rank)
    print(f"Rank: {rank}, World size: {world_size}, GPU memory: {total / 1024**3:.2f}GB", flush=True)
    time.sleep(world_size - rank)

    # Seed
    set_seed(cfg.seed+rank)

    # Run
    cfg.local_rank= rank
    cfg.world_size= world_size
    main(cfg)
    cleanup()
# Out:
# Overwriting _train.py

# %%
if RUN_TRAIN:
    print("Starting training..")
    # !OMP_NUM_THREADS=1 torchrun --nproc_per_node=2 _train.py
# Out:
# Starting training..
# 2025-07-01 10:53:08.560519: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-01 10:53:08.587400: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-01 10:53:08.612759: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-01 10:53:08.612785: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-01 10:53:08.614649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-01 10:53:08.623135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-01 10:53:08.632818: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-01 10:53:08.632843: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-01 10:53:08.634459: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-01 10:53:08.642867: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-01 10:53:09.612909: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-07-01 10:53:09.616157: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Rank: 0, World size: 2, GPU memory: 23.65GB
# Rank: 1, World size: 2, GPU memory: 23.65GB
# =========================
# Loading data..
# 100%|███████████████████████████████████████| 920/920 [00:00<00:00, 1615.84it/s]
# 100%|█████████████████████████████████████████| 20/20 [00:00<00:00, 2549.19it/s]
# /root/miniconda3/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Initializing EMA model..
# =========================
# Give me warp 2, Mr. Sulu.
# =========================
# 100%|█████████████████████████████████████████| 313/313 [00:39<00:00,  7.84it/s]
# Saved weights latest..
# New best: 1000000.00 -> 24.07
# Saved weights..
# /root/miniconda3/lib/python3.10/site-packages/torch/autograd/__init__.py:251: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [256, 1024, 1, 1], strides() = [1024, 1, 1024, 1024]
# bucket_view.sizes() = [256, 1024, 1, 1], strides() = [1024, 1, 1, 1] (Triggered internally at ../torch/csrc/distributed/c10d/reducer.cpp:320.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /root/miniconda3/lib/python3.10/site-packages/torch/autograd/__init__.py:251: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [256, 1024, 1, 1], strides() = [1024, 1, 1024, 1024]
# bucket_view.sizes() = [256, 1024, 1, 1], strides() = [1024, 1, 1, 1] (Triggered internally at ../torch/csrc/distributed/c10d/reducer.cpp:320.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 1:     Train MAE: 9.31     Val MAE: 24.07     LR: 0.0001     Time: 0:00:07     Step: 1/14376
# Epoch 1:     Train MAE: 19.84     Val MAE: 24.07     LR: 0.0001     Time: 0:00:30     Step: 101/14376
# Epoch 1:     Train MAE: 17.40     Val MAE: 24.07     LR: 0.0001     Time: 0:00:53     Step: 201/14376
# Epoch 1:     Train MAE: 16.39     Val MAE: 24.07     LR: 0.0001     Time: 0:01:16     Step: 301/14376
# Epoch 1:     Train MAE: 19.69     Val MAE: 24.07     LR: 0.0001     Time: 0:01:39     Step: 401/14376
# Epoch 1:     Train MAE: 20.24     Val MAE: 24.07     LR: 0.0001     Time: 0:02:02     Step: 501/14376
# Epoch 1:     Train MAE: 19.91     Val MAE: 24.07     LR: 0.0001     Time: 0:02:24     Step: 601/14376
# Epoch 1:     Train MAE: 19.18     Val MAE: 24.07     LR: 0.0001     Time: 0:02:47     Step: 701/14376
# Epoch 1:     Train MAE: 18.06     Val MAE: 24.07     LR: 0.0001     Time: 0:03:10     Step: 801/14376
# Epoch 1:     Train MAE: 18.42     Val MAE: 24.07     LR: 0.0001     Time: 0:03:33     Step: 901/14376
# Epoch 1:     Train MAE: 19.93     Val MAE: 24.07     LR: 0.0001     Time: 0:03:55     Step: 1001/14376
# Epoch 1:     Train MAE: 23.40     Val MAE: 24.07     LR: 0.0001     Time: 0:04:18     Step: 1101/14376
# Epoch 1:     Train MAE: 19.86     Val MAE: 24.07     LR: 0.0001     Time: 0:04:41     Step: 1201/14376
# Epoch 1:     Train MAE: 20.75     Val MAE: 24.07     LR: 0.0001     Time: 0:05:03     Step: 1301/14376
# Epoch 1:     Train MAE: 24.99     Val MAE: 24.07     LR: 0.0001     Time: 0:05:26     Step: 1401/14376
# Epoch 1:     Train MAE: 21.38     Val MAE: 24.07     LR: 0.0001     Time: 0:05:50     Step: 1501/14376
# Epoch 1:     Train MAE: 20.97     Val MAE: 24.07     LR: 0.0001     Time: 0:06:12     Step: 1601/14376
# Epoch 1:     Train MAE: 19.79     Val MAE: 24.07     LR: 0.0001     Time: 0:06:35     Step: 1701/14376
# Epoch 1:     Train MAE: 23.35     Val MAE: 24.07     LR: 0.0001     Time: 0:06:58     Step: 1801/14376
# Epoch 1:     Train MAE: 26.34     Val MAE: 24.07     LR: 0.0001     Time: 0:07:21     Step: 1901/14376
# Epoch 1:     Train MAE: 22.21     Val MAE: 24.07     LR: 0.0001     Time: 0:07:43     Step: 2001/14376
# Epoch 1:     Train MAE: 20.40     Val MAE: 24.07     LR: 0.0001     Time: 0:08:06     Step: 2101/14376
# Epoch 1:     Train MAE: 20.39     Val MAE: 24.07     LR: 0.0001     Time: 0:08:29     Step: 2201/14376
# Epoch 1:     Train MAE: 21.23     Val MAE: 24.07     LR: 0.0001     Time: 0:08:52     Step: 2301/14376
# Epoch 1:     Train MAE: 22.44     Val MAE: 24.07     LR: 0.0001     Time: 0:09:14     Step: 2401/14376
# Epoch 1:     Train MAE: 21.76     Val MAE: 24.07     LR: 0.0001     Time: 0:09:37     Step: 2501/14376
# Epoch 1:     Train MAE: 19.95     Val MAE: 24.07     LR: 0.0001     Time: 0:10:00     Step: 2601/14376
# Epoch 1:     Train MAE: 23.23     Val MAE: 24.07     LR: 0.0001     Time: 0:10:22     Step: 2701/14376
# Epoch 1:     Train MAE: 20.84     Val MAE: 24.07     LR: 0.0001     Time: 0:10:46     Step: 2801/14376
# Epoch 1:     Train MAE: 22.83     Val MAE: 24.07     LR: 0.0001     Time: 0:11:08     Step: 2901/14376
# Epoch 1:     Train MAE: 23.72     Val MAE: 24.07     LR: 0.0001     Time: 0:11:31     Step: 3001/14376
# Epoch 1:     Train MAE: 22.26     Val MAE: 24.07     LR: 0.0001     Time: 0:11:54     Step: 3101/14376
# Epoch 1:     Train MAE: 22.43     Val MAE: 24.07     LR: 0.0001     Time: 0:12:16     Step: 3201/14376
# Epoch 1:     Train MAE: 19.80     Val MAE: 24.07     LR: 0.0001     Time: 0:12:39     Step: 3301/14376
# Epoch 1:     Train MAE: 23.93     Val MAE: 24.07     LR: 0.0001     Time: 0:13:02     Step: 3401/14376
# Epoch 1:     Train MAE: 20.21     Val MAE: 24.07     LR: 0.0001     Time: 0:13:25     Step: 3501/14376
# Epoch 1:     Train MAE: 23.29     Val MAE: 24.07     LR: 0.0001     Time: 0:13:48     Step: 3601/14376
# Epoch 1:     Train MAE: 25.20     Val MAE: 24.07     LR: 0.0001     Time: 0:14:10     Step: 3701/14376
# Epoch 1:     Train MAE: 23.49     Val MAE: 24.07     LR: 0.0001     Time: 0:14:33     Step: 3801/14376
# Epoch 1:     Train MAE: 23.20     Val MAE: 24.07     LR: 0.0001     Time: 0:14:56     Step: 3901/14376
# Epoch 1:     Train MAE: 26.06     Val MAE: 24.07     LR: 0.0001     Time: 0:15:19     Step: 4001/14376
# Epoch 1:     Train MAE: 22.00     Val MAE: 24.07     LR: 0.0001     Time: 0:15:42     Step: 4101/14376
# Epoch 1:     Train MAE: 21.69     Val MAE: 24.07     LR: 0.0001     Time: 0:16:05     Step: 4201/14376
# Epoch 1:     Train MAE: 23.41     Val MAE: 24.07     LR: 0.0001     Time: 0:16:27     Step: 4301/14376
# Epoch 1:     Train MAE: 23.17     Val MAE: 24.07     LR: 0.0001     Time: 0:16:50     Step: 4401/14376
# Epoch 1:     Train MAE: 22.05     Val MAE: 24.07     LR: 0.0001     Time: 0:17:12     Step: 4501/14376
# Epoch 1:     Train MAE: 23.36     Val MAE: 24.07     LR: 0.0001     Time: 0:17:35     Step: 4601/14376
# Epoch 1:     Train MAE: 22.97     Val MAE: 24.07     LR: 0.0001     Time: 0:17:58     Step: 4701/14376
# Epoch 1:     Train MAE: 22.89     Val MAE: 24.07     LR: 0.0001     Time: 0:18:21     Step: 4801/14376
# Epoch 1:     Train MAE: 24.46     Val MAE: 24.07     LR: 0.0001     Time: 0:18:44     Step: 4901/14376
# Epoch 1:     Train MAE: 21.52     Val MAE: 24.07     LR: 0.0001     Time: 0:19:07     Step: 5001/14376
# Epoch 1:     Train MAE: 21.98     Val MAE: 24.07     LR: 0.0001     Time: 0:19:29     Step: 5101/14376
# Epoch 1:     Train MAE: 22.66     Val MAE: 24.07     LR: 0.0001     Time: 0:19:52     Step: 5201/14376
# Epoch 1:     Train MAE: 21.48     Val MAE: 24.07     LR: 0.0001     Time: 0:20:15     Step: 5301/14376
# Epoch 1:     Train MAE: 21.28     Val MAE: 24.07     LR: 0.0001     Time: 0:20:38     Step: 5401/14376
# Epoch 1:     Train MAE: 23.15     Val MAE: 24.07     LR: 0.0001     Time: 0:21:00     Step: 5501/14376
# Epoch 1:     Train MAE: 23.33     Val MAE: 24.07     LR: 0.0001     Time: 0:21:23     Step: 5601/14376
# Epoch 1:     Train MAE: 21.74     Val MAE: 24.07     LR: 0.0001     Time: 0:21:45     Step: 5701/14376
# Epoch 1:     Train MAE: 22.53     Val MAE: 24.07     LR: 0.0001     Time: 0:22:08     Step: 5801/14376
# Epoch 1:     Train MAE: 23.43     Val MAE: 24.07     LR: 0.0001     Time: 0:22:30     Step: 5901/14376
# Epoch 1:     Train MAE: 21.07     Val MAE: 24.07     LR: 0.0001     Time: 0:22:53     Step: 6001/14376
# Epoch 1:     Train MAE: 24.59     Val MAE: 24.07     LR: 0.0001     Time: 0:23:16     Step: 6101/14376
# Epoch 1:     Train MAE: 24.91     Val MAE: 24.07     LR: 0.0001     Time: 0:23:39     Step: 6201/14376
# Epoch 1:     Train MAE: 22.30     Val MAE: 24.07     LR: 0.0001     Time: 0:24:01     Step: 6301/14376
# Epoch 1:     Train MAE: 21.97     Val MAE: 24.07     LR: 0.0001     Time: 0:24:24     Step: 6401/14376
# Epoch 1:     Train MAE: 22.65     Val MAE: 24.07     LR: 0.0001     Time: 0:24:46     Step: 6501/14376
# Epoch 1:     Train MAE: 21.16     Val MAE: 24.07     LR: 0.0001     Time: 0:25:09     Step: 6601/14376
# Epoch 1:     Train MAE: 22.62     Val MAE: 24.07     LR: 0.0001     Time: 0:25:32     Step: 6701/14376
# Epoch 1:     Train MAE: 22.01     Val MAE: 24.07     LR: 0.0001     Time: 0:25:55     Step: 6801/14376
# Epoch 1:     Train MAE: 20.63     Val MAE: 24.07     LR: 0.0001     Time: 0:26:18     Step: 6901/14376
# Epoch 1:     Train MAE: 22.14     Val MAE: 24.07     LR: 0.0001     Time: 0:26:40     Step: 7001/14376
# Epoch 1:     Train MAE: 22.13     Val MAE: 24.07     LR: 0.0001     Time: 0:27:03     Step: 7101/14376
# Epoch 1:     Train MAE: 24.44     Val MAE: 24.07     LR: 0.0001     Time: 0:27:26     Step: 7201/14376
# Epoch 1:     Train MAE: 23.05     Val MAE: 24.07     LR: 0.0001     Time: 0:27:49     Step: 7301/14376
# Epoch 1:     Train MAE: 20.95     Val MAE: 24.07     LR: 0.0001     Time: 0:28:12     Step: 7401/14376
# Epoch 1:     Train MAE: 22.06     Val MAE: 24.07     LR: 0.0001     Time: 0:28:34     Step: 7501/14376
# Epoch 1:     Train MAE: 23.98     Val MAE: 24.07     LR: 0.0001     Time: 0:28:57     Step: 7601/14376
# Epoch 1:     Train MAE: 23.50     Val MAE: 24.07     LR: 0.0001     Time: 0:29:20     Step: 7701/14376
# Epoch 1:     Train MAE: 23.42     Val MAE: 24.07     LR: 0.0001     Time: 0:29:42     Step: 7801/14376
# Epoch 1:     Train MAE: 32.12     Val MAE: 24.07     LR: 0.0001     Time: 0:30:05     Step: 7901/14376
# Epoch 1:     Train MAE: 31.76     Val MAE: 24.07     LR: 0.0001     Time: 0:30:28     Step: 8001/14376
# Epoch 1:     Train MAE: 28.33     Val MAE: 24.07     LR: 0.0001     Time: 0:30:51     Step: 8101/14376
# Epoch 1:     Train MAE: 27.18     Val MAE: 24.07     LR: 0.0001     Time: 0:31:14     Step: 8201/14376
# Epoch 1:     Train MAE: 25.37     Val MAE: 24.07     LR: 0.0001     Time: 0:31:36     Step: 8301/14376
# Epoch 1:     Train MAE: 23.75     Val MAE: 24.07     LR: 0.0001     Time: 0:31:59     Step: 8401/14376
# Epoch 1:     Train MAE: 22.06     Val MAE: 24.07     LR: 0.0001     Time: 0:32:21     Step: 8501/14376
# Epoch 1:     Train MAE: 23.25     Val MAE: 24.07     LR: 0.0001     Time: 0:32:44     Step: 8601/14376
# Epoch 1:     Train MAE: 25.01     Val MAE: 24.07     LR: 0.0001     Time: 0:33:07     Step: 8701/14376
# Epoch 1:     Train MAE: 23.57     Val MAE: 24.07     LR: 0.0001     Time: 0:33:30     Step: 8801/14376
# Epoch 1:     Train MAE: 23.53     Val MAE: 24.07     LR: 0.0001     Time: 0:33:52     Step: 8901/14376
# Epoch 1:     Train MAE: 22.34     Val MAE: 24.07     LR: 0.0001     Time: 0:34:15     Step: 9001/14376
# Epoch 1:     Train MAE: 22.02     Val MAE: 24.07     LR: 0.0001     Time: 0:34:37     Step: 9101/14376
# Epoch 1:     Train MAE: 23.37     Val MAE: 24.07     LR: 0.0001     Time: 0:35:00     Step: 9201/14376
# Epoch 1:     Train MAE: 23.41     Val MAE: 24.07     LR: 0.0001     Time: 0:35:23     Step: 9301/14376
# Epoch 1:     Train MAE: 22.66     Val MAE: 24.07     LR: 0.0001     Time: 0:35:46     Step: 9401/14376
# Epoch 1:     Train MAE: 21.37     Val MAE: 24.07     LR: 0.0001     Time: 0:36:09     Step: 9501/14376
# Epoch 1:     Train MAE: 23.16     Val MAE: 24.07     LR: 0.0001     Time: 0:36:31     Step: 9601/14376
# Epoch 1:     Train MAE: 21.98     Val MAE: 24.07     LR: 0.0001     Time: 0:36:54     Step: 9701/14376
# Epoch 1:     Train MAE: 20.20     Val MAE: 24.07     LR: 0.0001     Time: 0:37:17     Step: 9801/14376
# Epoch 1:     Train MAE: 25.08     Val MAE: 24.07     LR: 0.0001     Time: 0:37:40     Step: 9901/14376
# Epoch 1:     Train MAE: 22.52     Val MAE: 24.07     LR: 0.0001     Time: 0:38:03     Step: 10001/14376
# Epoch 1:     Train MAE: 21.34     Val MAE: 24.07     LR: 0.0001     Time: 0:38:25     Step: 10101/14376
# Epoch 1:     Train MAE: 24.28     Val MAE: 24.07     LR: 0.0001     Time: 0:38:48     Step: 10201/14376
# Epoch 1:     Train MAE: 24.28     Val MAE: 24.07     LR: 0.0001     Time: 0:39:11     Step: 10301/14376
# Epoch 1:     Train MAE: 24.05     Val MAE: 24.07     LR: 0.0001     Time: 0:39:33     Step: 10401/14376
# Epoch 1:     Train MAE: 19.88     Val MAE: 24.07     LR: 0.0001     Time: 0:39:56     Step: 10501/14376
# Epoch 1:     Train MAE: 22.17     Val MAE: 24.07     LR: 0.0001     Time: 0:40:19     Step: 10601/14376
# Epoch 1:     Train MAE: 22.39     Val MAE: 24.07     LR: 0.0001     Time: 0:40:41     Step: 10701/14376
# Epoch 1:     Train MAE: 21.19     Val MAE: 24.07     LR: 0.0001     Time: 0:41:04     Step: 10801/14376
# Epoch 1:     Train MAE: 23.27     Val MAE: 24.07     LR: 0.0001     Time: 0:41:27     Step: 10901/14376
# Epoch 1:     Train MAE: 24.36     Val MAE: 24.07     LR: 0.0001     Time: 0:41:49     Step: 11001/14376
# Epoch 1:     Train MAE: 25.04     Val MAE: 24.07     LR: 0.0001     Time: 0:42:12     Step: 11101/14376
# Epoch 1:     Train MAE: 24.05     Val MAE: 24.07     LR: 0.0001     Time: 0:42:35     Step: 11201/14376
# Epoch 1:     Train MAE: 24.36     Val MAE: 24.07     LR: 0.0001     Time: 0:42:58     Step: 11301/14376
# Epoch 1:     Train MAE: 22.48     Val MAE: 24.07     LR: 0.0001     Time: 0:43:20     Step: 11401/14376
# Epoch 1:     Train MAE: 22.63     Val MAE: 24.07     LR: 0.0001     Time: 0:43:43     Step: 11501/14376
# Epoch 1:     Train MAE: 22.29     Val MAE: 24.07     LR: 0.0001     Time: 0:44:06     Step: 11601/14376
# Epoch 1:     Train MAE: 22.58     Val MAE: 24.07     LR: 0.0001     Time: 0:44:28     Step: 11701/14376
# Epoch 1:     Train MAE: 22.76     Val MAE: 24.07     LR: 0.0001     Time: 0:44:51     Step: 11801/14376
# Epoch 1:     Train MAE: 22.09     Val MAE: 24.07     LR: 0.0001     Time: 0:45:14     Step: 11901/14376
# Epoch 1:     Train MAE: 21.93     Val MAE: 24.07     LR: 0.0001     Time: 0:45:37     Step: 12001/14376
# Epoch 1:     Train MAE: 22.09     Val MAE: 24.07     LR: 0.0001     Time: 0:45:59     Step: 12101/14376
# Epoch 1:     Train MAE: 22.17     Val MAE: 24.07     LR: 0.0001     Time: 0:46:22     Step: 12201/14376
# Epoch 1:     Train MAE: 21.79     Val MAE: 24.07     LR: 0.0001     Time: 0:46:45     Step: 12301/14376
# Epoch 1:     Train MAE: 23.03     Val MAE: 24.07     LR: 0.0001     Time: 0:47:07     Step: 12401/14376
# Epoch 1:     Train MAE: 24.14     Val MAE: 24.07     LR: 0.0001     Time: 0:47:31     Step: 12501/14376
# Epoch 1:     Train MAE: 22.54     Val MAE: 24.07     LR: 0.0001     Time: 0:47:53     Step: 12601/14376
# Epoch 1:     Train MAE: 24.05     Val MAE: 24.07     LR: 0.0001     Time: 0:48:16     Step: 12701/14376
# Epoch 1:     Train MAE: 23.32     Val MAE: 24.07     LR: 0.0001     Time: 0:48:39     Step: 12801/14376
# Epoch 1:     Train MAE: 23.51     Val MAE: 24.07     LR: 0.0001     Time: 0:49:01     Step: 12901/14376
# Epoch 1:     Train MAE: 21.65     Val MAE: 24.07     LR: 0.0001     Time: 0:49:24     Step: 13001/14376
# Epoch 1:     Train MAE: 22.55     Val MAE: 24.07     LR: 0.0001     Time: 0:49:47     Step: 13101/14376
# Epoch 1:     Train MAE: 23.87     Val MAE: 24.07     LR: 0.0001     Time: 0:50:10     Step: 13201/14376
# Epoch 1:     Train MAE: 24.07     Val MAE: 24.07     LR: 0.0001     Time: 0:50:33     Step: 13301/14376
# Epoch 1:     Train MAE: 23.32     Val MAE: 24.07     LR: 0.0001     Time: 0:50:56     Step: 13401/14376
# Epoch 1:     Train MAE: 23.84     Val MAE: 24.07     LR: 0.0001     Time: 0:51:18     Step: 13501/14376
# Epoch 1:     Train MAE: 21.58     Val MAE: 24.07     LR: 0.0001     Time: 0:51:41     Step: 13601/14376
# Epoch 1:     Train MAE: 24.31     Val MAE: 24.07     LR: 0.0001     Time: 0:52:04     Step: 13701/14376
# Epoch 1:     Train MAE: 23.60     Val MAE: 24.07     LR: 0.0001     Time: 0:52:27     Step: 13801/14376
# Epoch 1:     Train MAE: 24.54     Val MAE: 24.07     LR: 0.0001     Time: 0:52:50     Step: 13901/14376
# Epoch 1:     Train MAE: 25.34     Val MAE: 24.07     LR: 0.0001     Time: 0:53:12     Step: 14001/14376
# Epoch 1:     Train MAE: 21.62     Val MAE: 24.07     LR: 0.0001     Time: 0:53:35     Step: 14101/14376
# Epoch 1:     Train MAE: 21.61     Val MAE: 24.07     LR: 0.0001     Time: 0:53:58     Step: 14201/14376
# Epoch 1:     Train MAE: 22.35     Val MAE: 24.07     LR: 0.0001     Time: 0:54:20     Step: 14301/14376
# 100%|█████████████████████████████████████████| 313/313 [00:39<00:00,  7.83it/s]
# Saved weights latest..
# Epoch 2:     Train MAE: 20.47     Val MAE: 27.57     LR: 0.0001     Time: 0:00:06     Step: 1/14376
# Epoch 2:     Train MAE: 24.96     Val MAE: 27.57     LR: 0.0001     Time: 0:00:30     Step: 101/14376
# Epoch 2:     Train MAE: 24.98     Val MAE: 27.57     LR: 0.0001     Time: 0:00:53     Step: 201/14376
# Epoch 2:     Train MAE: 24.80     Val MAE: 27.57     LR: 0.0001     Time: 0:01:15     Step: 301/14376
# Epoch 2:     Train MAE: 22.77     Val MAE: 27.57     LR: 0.0001     Time: 0:01:38     Step: 401/14376
# Epoch 2:     Train MAE: 24.04     Val MAE: 27.57     LR: 0.0001     Time: 0:02:01     Step: 501/14376
# Epoch 2:     Train MAE: 22.74     Val MAE: 27.57     LR: 0.0001     Time: 0:02:24     Step: 601/14376
# Epoch 2:     Train MAE: 22.08     Val MAE: 27.57     LR: 0.0001     Time: 0:02:47     Step: 701/14376
# Epoch 2:     Train MAE: 21.94     Val MAE: 27.57     LR: 0.0001     Time: 0:03:10     Step: 801/14376
# Epoch 2:     Train MAE: 21.35     Val MAE: 27.57     LR: 0.0001     Time: 0:03:33     Step: 901/14376
# Epoch 2:     Train MAE: 24.02     Val MAE: 27.57     LR: 0.0001     Time: 0:03:55     Step: 1001/14376
# Epoch 2:     Train MAE: 22.54     Val MAE: 27.57     LR: 0.0001     Time: 0:04:18     Step: 1101/14376
# Epoch 2:     Train MAE: 23.20     Val MAE: 27.57     LR: 0.0001     Time: 0:04:41     Step: 1201/14376
# Epoch 2:     Train MAE: 23.42     Val MAE: 27.57     LR: 0.0001     Time: 0:05:04     Step: 1301/14376
# Epoch 2:     Train MAE: 27.38     Val MAE: 27.57     LR: 0.0001     Time: 0:05:27     Step: 1401/14376
# Epoch 2:     Train MAE: 25.46     Val MAE: 27.57     LR: 0.0001     Time: 0:05:49     Step: 1501/14376
# Epoch 2:     Train MAE: 23.65     Val MAE: 27.57     LR: 0.0001     Time: 0:06:12     Step: 1601/14376
# Epoch 2:     Train MAE: 22.87     Val MAE: 27.57     LR: 0.0001     Time: 0:06:35     Step: 1701/14376
# Epoch 2:     Train MAE: 23.54     Val MAE: 27.57     LR: 0.0001     Time: 0:06:58     Step: 1801/14376
# Epoch 2:     Train MAE: 24.39     Val MAE: 27.57     LR: 0.0001     Time: 0:07:21     Step: 1901/14376
# Epoch 2:     Train MAE: 22.56     Val MAE: 27.57     LR: 0.0001     Time: 0:07:44     Step: 2001/14376
# Epoch 2:     Train MAE: 23.42     Val MAE: 27.57     LR: 0.0001     Time: 0:08:07     Step: 2101/14376
# Epoch 2:     Train MAE: 22.38     Val MAE: 27.57     LR: 0.0001     Time: 0:08:29     Step: 2201/14376
# Epoch 2:     Train MAE: 21.66     Val MAE: 27.57     LR: 0.0001     Time: 0:08:52     Step: 2301/14376
# Epoch 2:     Train MAE: 24.25     Val MAE: 27.57     LR: 0.0001     Time: 0:09:15     Step: 2401/14376
# Epoch 2:     Train MAE: 24.21     Val MAE: 27.57     LR: 0.0001     Time: 0:09:37     Step: 2501/14376
# Epoch 2:     Train MAE: 23.67     Val MAE: 27.57     LR: 0.0001     Time: 0:10:00     Step: 2601/14376
# Epoch 2:     Train MAE: 24.22     Val MAE: 27.57     LR: 0.0001     Time: 0:10:23     Step: 2701/14376
# Epoch 2:     Train MAE: 25.82     Val MAE: 27.57     LR: 0.0001     Time: 0:10:46     Step: 2801/14376
# Epoch 2:     Train MAE: 21.89     Val MAE: 27.57     LR: 0.0001     Time: 0:11:09     Step: 2901/14376
# Epoch 2:     Train MAE: 23.35     Val MAE: 27.57     LR: 0.0001     Time: 0:11:31     Step: 3001/14376
# Epoch 2:     Train MAE: 24.93     Val MAE: 27.57     LR: 0.0001     Time: 0:11:54     Step: 3101/14376
# Epoch 2:     Train MAE: 24.23     Val MAE: 27.57     LR: 0.0001     Time: 0:12:17     Step: 3201/14376
# Epoch 2:     Train MAE: 24.16     Val MAE: 27.57     LR: 0.0001     Time: 0:12:40     Step: 3301/14376
# Epoch 2:     Train MAE: 26.52     Val MAE: 27.57     LR: 0.0001     Time: 0:13:03     Step: 3401/14376
# Epoch 2:     Train MAE: 25.56     Val MAE: 27.57     LR: 0.0001     Time: 0:13:26     Step: 3501/14376
# Epoch 2:     Train MAE: 23.83     Val MAE: 27.57     LR: 0.0001     Time: 0:13:48     Step: 3601/14376
# Epoch 2:     Train MAE: 23.47     Val MAE: 27.57     LR: 0.0001     Time: 0:14:11     Step: 3701/14376
# Epoch 2:     Train MAE: 24.08     Val MAE: 27.57     LR: 0.0001     Time: 0:14:34     Step: 3801/14376
# Epoch 2:     Train MAE: 22.13     Val MAE: 27.57     LR: 0.0001     Time: 0:14:57     Step: 3901/14376
# Epoch 2:     Train MAE: 23.57     Val MAE: 27.57     LR: 0.0001     Time: 0:15:20     Step: 4001/14376
# Epoch 2:     Train MAE: 21.81     Val MAE: 27.57     LR: 0.0001     Time: 0:15:42     Step: 4101/14376
# Epoch 2:     Train MAE: 23.31     Val MAE: 27.57     LR: 0.0001     Time: 0:16:05     Step: 4201/14376
# Epoch 2:     Train MAE: 25.92     Val MAE: 27.57     LR: 0.0001     Time: 0:16:28     Step: 4301/14376
# Epoch 2:     Train MAE: 25.19     Val MAE: 27.57     LR: 0.0001     Time: 0:16:51     Step: 4401/14376
# Epoch 2:     Train MAE: 27.16     Val MAE: 27.57     LR: 0.0001     Time: 0:17:14     Step: 4501/14376
# Epoch 2:     Train MAE: 23.38     Val MAE: 27.57     LR: 0.0001     Time: 0:17:37     Step: 4601/14376
# Epoch 2:     Train MAE: 22.72     Val MAE: 27.57     LR: 0.0001     Time: 0:17:59     Step: 4701/14376
# Epoch 2:     Train MAE: 23.44     Val MAE: 27.57     LR: 0.0001     Time: 0:18:22     Step: 4801/14376
# Epoch 2:     Train MAE: 23.84     Val MAE: 27.57     LR: 0.0001     Time: 0:18:45     Step: 4901/14376
# Epoch 2:     Train MAE: 23.91     Val MAE: 27.57     LR: 0.0001     Time: 0:19:08     Step: 5001/14376
# Epoch 2:     Train MAE: 24.36     Val MAE: 27.57     LR: 0.0001     Time: 0:19:30     Step: 5101/14376
# Epoch 2:     Train MAE: 23.47     Val MAE: 27.57     LR: 0.0001     Time: 0:19:54     Step: 5201/14376
# Epoch 2:     Train MAE: 22.10     Val MAE: 27.57     LR: 0.0001     Time: 0:20:16     Step: 5301/14376
# Epoch 2:     Train MAE: 23.57     Val MAE: 27.57     LR: 0.0001     Time: 0:20:39     Step: 5401/14376
# Epoch 2:     Train MAE: 23.44     Val MAE: 27.57     LR: 0.0001     Time: 0:21:02     Step: 5501/14376
# Epoch 2:     Train MAE: 24.13     Val MAE: 27.57     LR: 0.0001     Time: 0:21:25     Step: 5601/14376
# Epoch 2:     Train MAE: 23.57     Val MAE: 27.57     LR: 0.0001     Time: 0:21:47     Step: 5701/14376
# Epoch 2:     Train MAE: 22.83     Val MAE: 27.57     LR: 0.0001     Time: 0:22:10     Step: 5801/14376
# Epoch 2:     Train MAE: 25.62     Val MAE: 27.57     LR: 0.0001     Time: 0:22:33     Step: 5901/14376
# Epoch 2:     Train MAE: 24.90     Val MAE: 27.57     LR: 0.0001     Time: 0:22:56     Step: 6001/14376
# Epoch 2:     Train MAE: 26.98     Val MAE: 27.57     LR: 0.0001     Time: 0:23:19     Step: 6101/14376
# Epoch 2:     Train MAE: 27.38     Val MAE: 27.57     LR: 0.0001     Time: 0:23:41     Step: 6201/14376
# Epoch 2:     Train MAE: 25.21     Val MAE: 27.57     LR: 0.0001     Time: 0:24:04     Step: 6301/14376
# Epoch 2:     Train MAE: 27.90     Val MAE: 27.57     LR: 0.0001     Time: 0:24:27     Step: 6401/14376
# Epoch 2:     Train MAE: 25.04     Val MAE: 27.57     LR: 0.0001     Time: 0:24:50     Step: 6501/14376
# Epoch 2:     Train MAE: 25.16     Val MAE: 27.57     LR: 0.0001     Time: 0:25:12     Step: 6601/14376
# Epoch 2:     Train MAE: 25.37     Val MAE: 27.57     LR: 0.0001     Time: 0:25:35     Step: 6701/14376
# Epoch 2:     Train MAE: 24.75     Val MAE: 27.57     LR: 0.0001     Time: 0:25:58     Step: 6801/14376
# Epoch 2:     Train MAE: 23.78     Val MAE: 27.57     LR: 0.0001     Time: 0:26:20     Step: 6901/14376
# Epoch 2:     Train MAE: 28.93     Val MAE: 27.57     LR: 0.0001     Time: 0:26:43     Step: 7001/14376
# Epoch 2:     Train MAE: 23.49     Val MAE: 27.57     LR: 0.0001     Time: 0:27:06     Step: 7101/14376
# Epoch 2:     Train MAE: 23.19     Val MAE: 27.57     LR: 0.0001     Time: 0:27:29     Step: 7201/14376
# Epoch 2:     Train MAE: 22.98     Val MAE: 27.57     LR: 0.0001     Time: 0:27:52     Step: 7301/14376
# Epoch 2:     Train MAE: 24.31     Val MAE: 27.57     LR: 0.0001     Time: 0:28:14     Step: 7401/14376
# Epoch 2:     Train MAE: 22.77     Val MAE: 27.57     LR: 0.0001     Time: 0:28:37     Step: 7501/14376
# Epoch 2:     Train MAE: 23.40     Val MAE: 27.57     LR: 0.0001     Time: 0:29:00     Step: 7601/14376
# Epoch 2:     Train MAE: 22.28     Val MAE: 27.57     LR: 0.0001     Time: 0:29:23     Step: 7701/14376
# Epoch 2:     Train MAE: 22.58     Val MAE: 27.57     LR: 0.0001     Time: 0:29:46     Step: 7801/14376
# Epoch 2:     Train MAE: 23.30     Val MAE: 27.57     LR: 0.0001     Time: 0:30:09     Step: 7901/14376
# Epoch 2:     Train MAE: 23.39     Val MAE: 27.57     LR: 0.0001     Time: 0:30:31     Step: 8001/14376
# Epoch 2:     Train MAE: 23.51     Val MAE: 27.57     LR: 0.0001     Time: 0:30:54     Step: 8101/14376
# Epoch 2:     Train MAE: 23.74     Val MAE: 27.57     LR: 0.0001     Time: 0:31:17     Step: 8201/14376
# Epoch 2:     Train MAE: 23.36     Val MAE: 27.57     LR: 0.0001     Time: 0:31:40     Step: 8301/14376
# Epoch 2:     Train MAE: 22.12     Val MAE: 27.57     LR: 0.0001     Time: 0:32:03     Step: 8401/14376
# Epoch 2:     Train MAE: 22.32     Val MAE: 27.57     LR: 0.0001     Time: 0:32:25     Step: 8501/14376
# Epoch 2:     Train MAE: 24.59     Val MAE: 27.57     LR: 0.0001     Time: 0:32:48     Step: 8601/14376
# Epoch 2:     Train MAE: 25.40     Val MAE: 27.57     LR: 0.0001     Time: 0:33:10     Step: 8701/14376
# Epoch 2:     Train MAE: 25.33     Val MAE: 27.57     LR: 0.0001     Time: 0:33:33     Step: 8801/14376
# Epoch 2:     Train MAE: 24.88     Val MAE: 27.57     LR: 0.0001     Time: 0:33:56     Step: 8901/14376
# Epoch 2:     Train MAE: 26.09     Val MAE: 27.57     LR: 0.0001     Time: 0:34:19     Step: 9001/14376
# Epoch 2:     Train MAE: 25.77     Val MAE: 27.57     LR: 0.0001     Time: 0:34:42     Step: 9101/14376
# Epoch 2:     Train MAE: 26.28     Val MAE: 27.57     LR: 0.0001     Time: 0:35:05     Step: 9201/14376
# Epoch 2:     Train MAE: 24.07     Val MAE: 27.57     LR: 0.0001     Time: 0:35:27     Step: 9301/14376
# Epoch 2:     Train MAE: 25.72     Val MAE: 27.57     LR: 0.0001     Time: 0:35:50     Step: 9401/14376
# Epoch 2:     Train MAE: 23.62     Val MAE: 27.57     LR: 0.0001     Time: 0:36:12     Step: 9501/14376
# Epoch 2:     Train MAE: 23.93     Val MAE: 27.57     LR: 0.0001     Time: 0:36:35     Step: 9601/14376
# Epoch 2:     Train MAE: 24.77     Val MAE: 27.57     LR: 0.0001     Time: 0:36:58     Step: 9701/14376
# Epoch 2:     Train MAE: 21.96     Val MAE: 27.57     LR: 0.0001     Time: 0:37:21     Step: 9801/14376
# Epoch 2:     Train MAE: 25.35     Val MAE: 27.57     LR: 0.0001     Time: 0:37:43     Step: 9901/14376
# Epoch 2:     Train MAE: 26.27     Val MAE: 27.57     LR: 0.0001     Time: 0:38:06     Step: 10001/14376
# Epoch 2:     Train MAE: 24.68     Val MAE: 27.57     LR: 0.0001     Time: 0:38:29     Step: 10101/14376
# Epoch 2:     Train MAE: 25.18     Val MAE: 27.57     LR: 0.0001     Time: 0:38:52     Step: 10201/14376
# Epoch 2:     Train MAE: 27.53     Val MAE: 27.57     LR: 0.0001     Time: 0:39:14     Step: 10301/14376
# Epoch 2:     Train MAE: 23.96     Val MAE: 27.57     LR: 0.0001     Time: 0:39:37     Step: 10401/14376
# Epoch 2:     Train MAE: 24.21     Val MAE: 27.57     LR: 0.0001     Time: 0:40:00     Step: 10501/14376
# Epoch 2:     Train MAE: 26.16     Val MAE: 27.57     LR: 0.0001     Time: 0:40:23     Step: 10601/14376
# Epoch 2:     Train MAE: 24.98     Val MAE: 27.57     LR: 0.0001     Time: 0:40:45     Step: 10701/14376
# Epoch 2:     Train MAE: 23.32     Val MAE: 27.57     LR: 0.0001     Time: 0:41:08     Step: 10801/14376
# Epoch 2:     Train MAE: 23.58     Val MAE: 27.57     LR: 0.0001     Time: 0:41:31     Step: 10901/14376
# Epoch 2:     Train MAE: 23.08     Val MAE: 27.57     LR: 0.0001     Time: 0:41:54     Step: 11001/14376
# Epoch 2:     Train MAE: 22.92     Val MAE: 27.57     LR: 0.0001     Time: 0:42:16     Step: 11101/14376
# Epoch 2:     Train MAE: 25.55     Val MAE: 27.57     LR: 0.0001     Time: 0:42:39     Step: 11201/14376
# Epoch 2:     Train MAE: 26.93     Val MAE: 27.57     LR: 0.0001     Time: 0:43:02     Step: 11301/14376
# Epoch 2:     Train MAE: 27.09     Val MAE: 27.57     LR: 0.0001     Time: 0:43:24     Step: 11401/14376
# Epoch 2:     Train MAE: 23.46     Val MAE: 27.57     LR: 0.0001     Time: 0:43:47     Step: 11501/14376
# Epoch 2:     Train MAE: 23.07     Val MAE: 27.57     LR: 0.0001     Time: 0:44:10     Step: 11601/14376
# Epoch 2:     Train MAE: 22.87     Val MAE: 27.57     LR: 0.0001     Time: 0:44:33     Step: 11701/14376
# Epoch 2:     Train MAE: 21.59     Val MAE: 27.57     LR: 0.0001     Time: 0:44:56     Step: 11801/14376
# Epoch 2:     Train MAE: 23.15     Val MAE: 27.57     LR: 0.0001     Time: 0:45:19     Step: 11901/14376
# Epoch 2:     Train MAE: 23.77     Val MAE: 27.57     LR: 0.0001     Time: 0:45:41     Step: 12001/14376
# Epoch 2:     Train MAE: 24.83     Val MAE: 27.57     LR: 0.0001     Time: 0:46:04     Step: 12101/14376
# Epoch 2:     Train MAE: 23.41     Val MAE: 27.57     LR: 0.0001     Time: 0:46:26     Step: 12201/14376
# Epoch 2:     Train MAE: 24.85     Val MAE: 27.57     LR: 0.0001     Time: 0:46:50     Step: 12301/14376
# Epoch 2:     Train MAE: 22.87     Val MAE: 27.57     LR: 0.0001     Time: 0:47:12     Step: 12401/14376
# Epoch 2:     Train MAE: 24.31     Val MAE: 27.57     LR: 0.0001     Time: 0:47:35     Step: 12501/14376
# Epoch 2:     Train MAE: 24.30     Val MAE: 27.57     LR: 0.0001     Time: 0:47:58     Step: 12601/14376
# Epoch 2:     Train MAE: 24.00     Val MAE: 27.57     LR: 0.0001     Time: 0:48:20     Step: 12701/14376
# Epoch 2:     Train MAE: 22.80     Val MAE: 27.57     LR: 0.0001     Time: 0:48:43     Step: 12801/14376
# Epoch 2:     Train MAE: 23.82     Val MAE: 27.57     LR: 0.0001     Time: 0:49:05     Step: 12901/14376
# Epoch 2:     Train MAE: 27.26     Val MAE: 27.57     LR: 0.0001     Time: 0:49:29     Step: 13001/14376
# Epoch 2:     Train MAE: 25.67     Val MAE: 27.57     LR: 0.0001     Time: 0:49:51     Step: 13101/14376
# Epoch 2:     Train MAE: 21.80     Val MAE: 27.57     LR: 0.0001     Time: 0:50:14     Step: 13201/14376
# Epoch 2:     Train MAE: 22.46     Val MAE: 27.57     LR: 0.0001     Time: 0:50:37     Step: 13301/14376
# Epoch 2:     Train MAE: 27.60     Val MAE: 27.57     LR: 0.0001     Time: 0:50:59     Step: 13401/14376
# Epoch 2:     Train MAE: 24.17     Val MAE: 27.57     LR: 0.0001     Time: 0:51:22     Step: 13501/14376
# Epoch 2:     Train MAE: 25.96     Val MAE: 27.57     LR: 0.0001     Time: 0:51:45     Step: 13601/14376
# Epoch 2:     Train MAE: 23.59     Val MAE: 27.57     LR: 0.0001     Time: 0:52:08     Step: 13701/14376
# Epoch 2:     Train MAE: 24.56     Val MAE: 27.57     LR: 0.0001     Time: 0:52:31     Step: 13801/14376
# Epoch 2:     Train MAE: 24.81     Val MAE: 27.57     LR: 0.0001     Time: 0:52:53     Step: 13901/14376
# Epoch 2:     Train MAE: 26.32     Val MAE: 27.57     LR: 0.0001     Time: 0:53:16     Step: 14001/14376
# Epoch 2:     Train MAE: 24.13     Val MAE: 27.57     LR: 0.0001     Time: 0:53:39     Step: 14101/14376
# Epoch 2:     Train MAE: 24.82     Val MAE: 27.57     LR: 0.0001     Time: 0:54:02     Step: 14201/14376
# Epoch 2:     Train MAE: 25.74     Val MAE: 27.57     LR: 0.0001     Time: 0:54:25     Step: 14301/14376
# 100%|█████████████████████████████████████████| 313/313 [00:39<00:00,  7.83it/s]
# Saved weights latest..
# Epoch 3:     Train MAE: 31.25     Val MAE: 28.76     LR: 0.0001     Time: 0:00:06     Step: 1/14376
# Epoch 3:     Train MAE: 25.76     Val MAE: 28.76     LR: 0.0001     Time: 0:00:29     Step: 101/14376
# Epoch 3:     Train MAE: 23.27     Val MAE: 28.76     LR: 0.0001     Time: 0:00:51     Step: 201/14376
# Epoch 3:     Train MAE: 24.44     Val MAE: 28.76     LR: 0.0001     Time: 0:01:14     Step: 301/14376
# Epoch 3:     Train MAE: 23.42     Val MAE: 28.76     LR: 0.0001     Time: 0:01:37     Step: 401/14376
# Epoch 3:     Train MAE: 25.72     Val MAE: 28.76     LR: 0.0001     Time: 0:02:00     Step: 501/14376
# Epoch 3:     Train MAE: 26.67     Val MAE: 28.76     LR: 0.0001     Time: 0:02:23     Step: 601/14376
# Epoch 3:     Train MAE: 24.78     Val MAE: 28.76     LR: 0.0001     Time: 0:02:46     Step: 701/14376
# Epoch 3:     Train MAE: 24.55     Val MAE: 28.76     LR: 0.0001     Time: 0:03:08     Step: 801/14376
# Epoch 3:     Train MAE: 22.92     Val MAE: 28.76     LR: 0.0001     Time: 0:03:31     Step: 901/14376
# Epoch 3:     Train MAE: 26.32     Val MAE: 28.76     LR: 0.0001     Time: 0:03:54     Step: 1001/14376
# Epoch 3:     Train MAE: 24.86     Val MAE: 28.76     LR: 0.0001     Time: 0:04:17     Step: 1101/14376
# Epoch 3:     Train MAE: 23.81     Val MAE: 28.76     LR: 0.0001     Time: 0:04:40     Step: 1201/14376
# Epoch 3:     Train MAE: 23.58     Val MAE: 28.76     LR: 0.0001     Time: 0:05:03     Step: 1301/14376
# Epoch 3:     Train MAE: 23.21     Val MAE: 28.76     LR: 0.0001     Time: 0:05:25     Step: 1401/14376
# Epoch 3:     Train MAE: 24.14     Val MAE: 28.76     LR: 0.0001     Time: 0:05:48     Step: 1501/14376
# Epoch 3:     Train MAE: 23.04     Val MAE: 28.76     LR: 0.0001     Time: 0:06:11     Step: 1601/14376
# Epoch 3:     Train MAE: 23.66     Val MAE: 28.76     LR: 0.0001     Time: 0:06:34     Step: 1701/14376
# Epoch 3:     Train MAE: 23.18     Val MAE: 28.76     LR: 0.0001     Time: 0:06:57     Step: 1801/14376
# Epoch 3:     Train MAE: 22.54     Val MAE: 28.76     LR: 0.0001     Time: 0:07:19     Step: 1901/14376
# Epoch 3:     Train MAE: 24.31     Val MAE: 28.76     LR: 0.0001     Time: 0:07:42     Step: 2001/14376
# Epoch 3:     Train MAE: 22.37     Val MAE: 28.76     LR: 0.0001     Time: 0:08:05     Step: 2101/14376
# Epoch 3:     Train MAE: 22.99     Val MAE: 28.76     LR: 0.0001     Time: 0:08:27     Step: 2201/14376
# Epoch 3:     Train MAE: 23.81     Val MAE: 28.76     LR: 0.0001     Time: 0:08:50     Step: 2301/14376
# Epoch 3:     Train MAE: 24.83     Val MAE: 28.76     LR: 0.0001     Time: 0:09:13     Step: 2401/14376
# Epoch 3:     Train MAE: 25.11     Val MAE: 28.76     LR: 0.0001     Time: 0:09:36     Step: 2501/14376
# Epoch 3:     Train MAE: 27.20     Val MAE: 28.76     LR: 0.0001     Time: 0:09:59     Step: 2601/14376
# Epoch 3:     Train MAE: 25.69     Val MAE: 28.76     LR: 0.0001     Time: 0:10:21     Step: 2701/14376
# Epoch 3:     Train MAE: 26.31     Val MAE: 28.76     LR: 0.0001     Time: 0:10:44     Step: 2801/14376
# Epoch 3:     Train MAE: 24.46     Val MAE: 28.76     LR: 0.0001     Time: 0:11:07     Step: 2901/14376
# Epoch 3:     Train MAE: 23.31     Val MAE: 28.76     LR: 0.0001     Time: 0:11:29     Step: 3001/14376
# Epoch 3:     Train MAE: 23.36     Val MAE: 28.76     LR: 0.0001     Time: 0:11:53     Step: 3101/14376
# Epoch 3:     Train MAE: 23.59     Val MAE: 28.76     LR: 0.0001     Time: 0:12:15     Step: 3201/14376
# Epoch 3:     Train MAE: 24.18     Val MAE: 28.76     LR: 0.0001     Time: 0:12:38     Step: 3301/14376
# Epoch 3:     Train MAE: 24.68     Val MAE: 28.76     LR: 0.0001     Time: 0:13:01     Step: 3401/14376
# Epoch 3:     Train MAE: 23.13     Val MAE: 28.76     LR: 0.0001     Time: 0:13:23     Step: 3501/14376
# Epoch 3:     Train MAE: 23.71     Val MAE: 28.76     LR: 0.0001     Time: 0:13:46     Step: 3601/14376
# Epoch 3:     Train MAE: 24.63     Val MAE: 28.76     LR: 0.0001     Time: 0:14:09     Step: 3701/14376
# Epoch 3:     Train MAE: 27.09     Val MAE: 28.76     LR: 0.0001     Time: 0:14:32     Step: 3801/14376
# Epoch 3:     Train MAE: 23.91     Val MAE: 28.76     LR: 0.0001     Time: 0:14:55     Step: 3901/14376
# Epoch 3:     Train MAE: 25.94     Val MAE: 28.76     LR: 0.0001     Time: 0:15:18     Step: 4001/14376
# Epoch 3:     Train MAE: 25.09     Val MAE: 28.76     LR: 0.0001     Time: 0:15:40     Step: 4101/14376
# Epoch 3:     Train MAE: 26.28     Val MAE: 28.76     LR: 0.0001     Time: 0:16:03     Step: 4201/14376
# Epoch 3:     Train MAE: 22.57     Val MAE: 28.76     LR: 0.0001     Time: 0:16:26     Step: 4301/14376
# Epoch 3:     Train MAE: 22.74     Val MAE: 28.76     LR: 0.0001     Time: 0:16:49     Step: 4401/14376
# Epoch 3:     Train MAE: 23.03     Val MAE: 28.76     LR: 0.0001     Time: 0:17:12     Step: 4501/14376
# Epoch 3:     Train MAE: 24.54     Val MAE: 28.76     LR: 0.0001     Time: 0:17:34     Step: 4601/14376
# Epoch 3:     Train MAE: 25.53     Val MAE: 28.76     LR: 0.0001     Time: 0:17:57     Step: 4701/14376
# Epoch 3:     Train MAE: 23.91     Val MAE: 28.76     LR: 0.0001     Time: 0:18:20     Step: 4801/14376
# Epoch 3:     Train MAE: 23.20     Val MAE: 28.76     LR: 0.0001     Time: 0:18:43     Step: 4901/14376
# Epoch 3:     Train MAE: 23.75     Val MAE: 28.76     LR: 0.0001     Time: 0:19:06     Step: 5001/14376
# Epoch 3:     Train MAE: 24.95     Val MAE: 28.76     LR: 0.0001     Time: 0:19:29     Step: 5101/14376
# Epoch 3:     Train MAE: 22.82     Val MAE: 28.76     LR: 0.0001     Time: 0:19:51     Step: 5201/14376
# Epoch 3:     Train MAE: 25.01     Val MAE: 28.76     LR: 0.0001     Time: 0:20:14     Step: 5301/14376
# Epoch 3:     Train MAE: 23.42     Val MAE: 28.76     LR: 0.0001     Time: 0:20:37     Step: 5401/14376
# Epoch 3:     Train MAE: 22.87     Val MAE: 28.76     LR: 0.0001     Time: 0:21:00     Step: 5501/14376
# Epoch 3:     Train MAE: 24.57     Val MAE: 28.76     LR: 0.0001     Time: 0:21:22     Step: 5601/14376
# Epoch 3:     Train MAE: 24.79     Val MAE: 28.76     LR: 0.0001     Time: 0:21:46     Step: 5701/14376
# Epoch 3:     Train MAE: 26.65     Val MAE: 28.76     LR: 0.0001     Time: 0:22:08     Step: 5801/14376
# Epoch 3:     Train MAE: 25.23     Val MAE: 28.76     LR: 0.0001     Time: 0:22:31     Step: 5901/14376
# Epoch 3:     Train MAE: 24.49     Val MAE: 28.76     LR: 0.0001     Time: 0:22:53     Step: 6001/14376
# Epoch 3:     Train MAE: 23.34     Val MAE: 28.76     LR: 0.0001     Time: 0:23:16     Step: 6101/14376
# Epoch 3:     Train MAE: 21.29     Val MAE: 28.76     LR: 0.0001     Time: 0:23:39     Step: 6201/14376
# Epoch 3:     Train MAE: 22.52     Val MAE: 28.76     LR: 0.0001     Time: 0:24:02     Step: 6301/14376
# Epoch 3:     Train MAE: 24.50     Val MAE: 28.76     LR: 0.0001     Time: 0:24:25     Step: 6401/14376
# Epoch 3:     Train MAE: 23.67     Val MAE: 28.76     LR: 0.0001     Time: 0:24:47     Step: 6501/14376
# Epoch 3:     Train MAE: 26.06     Val MAE: 28.76     LR: 0.0001     Time: 0:25:10     Step: 6601/14376
# Epoch 3:     Train MAE: 27.82     Val MAE: 28.76     LR: 0.0001     Time: 0:25:33     Step: 6701/14376
# Epoch 3:     Train MAE: 24.43     Val MAE: 28.76     LR: 0.0001     Time: 0:25:55     Step: 6801/14376
# Epoch 3:     Train MAE: 22.73     Val MAE: 28.76     LR: 0.0001     Time: 0:26:18     Step: 6901/14376
# Epoch 3:     Train MAE: 23.37     Val MAE: 28.76     LR: 0.0001     Time: 0:26:41     Step: 7001/14376
# Epoch 3:     Train MAE: 24.48     Val MAE: 28.76     LR: 0.0001     Time: 0:27:04     Step: 7101/14376
# Epoch 3:     Train MAE: 25.44     Val MAE: 28.76     LR: 0.0001     Time: 0:27:27     Step: 7201/14376
# Epoch 3:     Train MAE: 27.01     Val MAE: 28.76     LR: 0.0001     Time: 0:27:49     Step: 7301/14376
# Epoch 3:     Train MAE: 23.48     Val MAE: 28.76     LR: 0.0001     Time: 0:28:12     Step: 7401/14376
# Epoch 3:     Train MAE: 22.98     Val MAE: 28.76     LR: 0.0001     Time: 0:28:35     Step: 7501/14376
# Epoch 3:     Train MAE: 23.29     Val MAE: 28.76     LR: 0.0001     Time: 0:28:58     Step: 7601/14376
# Epoch 3:     Train MAE: 24.22     Val MAE: 28.76     LR: 0.0001     Time: 0:29:21     Step: 7701/14376
# Epoch 3:     Train MAE: 23.92     Val MAE: 28.76     LR: 0.0001     Time: 0:29:43     Step: 7801/14376
# Epoch 3:     Train MAE: 23.71     Val MAE: 28.76     LR: 0.0001     Time: 0:30:06     Step: 7901/14376
# Epoch 3:     Train MAE: 22.80     Val MAE: 28.76     LR: 0.0001     Time: 0:30:29     Step: 8001/14376
# Epoch 3:     Train MAE: 22.94     Val MAE: 28.76     LR: 0.0001     Time: 0:30:51     Step: 8101/14376
# Epoch 3:     Train MAE: 23.06     Val MAE: 28.76     LR: 0.0001     Time: 0:31:14     Step: 8201/14376
# Epoch 3:     Train MAE: 22.86     Val MAE: 28.76     LR: 0.0001     Time: 0:31:37     Step: 8301/14376
# Epoch 3:     Train MAE: 21.48     Val MAE: 28.76     LR: 0.0001     Time: 0:32:00     Step: 8401/14376
# Epoch 3:     Train MAE: 23.65     Val MAE: 28.76     LR: 0.0001     Time: 0:32:23     Step: 8501/14376
# Epoch 3:     Train MAE: 26.57     Val MAE: 28.76     LR: 0.0001     Time: 0:32:46     Step: 8601/14376
# Epoch 3:     Train MAE: 25.29     Val MAE: 28.76     LR: 0.0001     Time: 0:33:08     Step: 8701/14376
# Epoch 3:     Train MAE: 26.14     Val MAE: 28.76     LR: 0.0001     Time: 0:33:31     Step: 8801/14376
# Epoch 3:     Train MAE: 24.59     Val MAE: 28.76     LR: 0.0001     Time: 0:33:54     Step: 8901/14376
# Epoch 3:     Train MAE: 24.13     Val MAE: 28.76     LR: 0.0001     Time: 0:34:17     Step: 9001/14376
# Epoch 3:     Train MAE: 23.24     Val MAE: 28.76     LR: 0.0001     Time: 0:34:40     Step: 9101/14376
# Epoch 3:     Train MAE: 24.34     Val MAE: 28.76     LR: 0.0001     Time: 0:35:02     Step: 9201/14376
# Epoch 3:     Train MAE: 25.57     Val MAE: 28.76     LR: 0.0001     Time: 0:35:25     Step: 9301/14376
# Epoch 3:     Train MAE: 25.17     Val MAE: 28.76     LR: 0.0001     Time: 0:35:48     Step: 9401/14376
# Epoch 3:     Train MAE: 23.71     Val MAE: 28.76     LR: 0.0001     Time: 0:36:11     Step: 9501/14376
# Epoch 3:     Train MAE: 22.00     Val MAE: 28.76     LR: 0.0001     Time: 0:36:34     Step: 9601/14376
# Epoch 3:     Train MAE: 23.37     Val MAE: 28.76     LR: 0.0001     Time: 0:36:57     Step: 9701/14376
# Epoch 3:     Train MAE: 23.12     Val MAE: 28.76     LR: 0.0001     Time: 0:37:19     Step: 9801/14376
# Epoch 3:     Train MAE: 24.61     Val MAE: 28.76     LR: 0.0001     Time: 0:37:42     Step: 9901/14376
# Epoch 3:     Train MAE: 22.44     Val MAE: 28.76     LR: 0.0001     Time: 0:38:05     Step: 10001/14376
# Epoch 3:     Train MAE: 22.43     Val MAE: 28.76     LR: 0.0001     Time: 0:38:27     Step: 10101/14376
# Epoch 3:     Train MAE: 22.85     Val MAE: 28.76     LR: 0.0001     Time: 0:38:51     Step: 10201/14376
# Epoch 3:     Train MAE: 24.01     Val MAE: 28.76     LR: 0.0001     Time: 0:39:13     Step: 10301/14376
# Epoch 3:     Train MAE: 24.60     Val MAE: 28.76     LR: 0.0001     Time: 0:39:36     Step: 10401/14376
# Epoch 3:     Train MAE: 27.06     Val MAE: 28.76     LR: 0.0001     Time: 0:39:59     Step: 10501/14376
# Epoch 3:     Train MAE: 23.36     Val MAE: 28.76     LR: 0.0001     Time: 0:40:21     Step: 10601/14376
# Epoch 3:     Train MAE: 23.14     Val MAE: 28.76     LR: 0.0001     Time: 0:40:44     Step: 10701/14376
# Epoch 3:     Train MAE: 25.23     Val MAE: 28.76     LR: 0.0001     Time: 0:41:08     Step: 10801/14376
# Epoch 3:     Train MAE: 23.42     Val MAE: 28.76     LR: 0.0001     Time: 0:41:30     Step: 10901/14376
# Epoch 3:     Train MAE: 23.62     Val MAE: 28.76     LR: 0.0001     Time: 0:41:53     Step: 11001/14376
# Epoch 3:     Train MAE: 25.01     Val MAE: 28.76     LR: 0.0001     Time: 0:42:16     Step: 11101/14376
# Epoch 3:     Train MAE: 23.10     Val MAE: 28.76     LR: 0.0001     Time: 0:42:38     Step: 11201/14376
# Epoch 3:     Train MAE: 23.18     Val MAE: 28.76     LR: 0.0001     Time: 0:43:01     Step: 11301/14376
# Epoch 3:     Train MAE: 24.19     Val MAE: 28.76     LR: 0.0001     Time: 0:43:24     Step: 11401/14376
# Epoch 3:     Train MAE: 23.49     Val MAE: 28.76     LR: 0.0001     Time: 0:43:47     Step: 11501/14376
# Epoch 3:     Train MAE: 23.63     Val MAE: 28.76     LR: 0.0001     Time: 0:44:10     Step: 11601/14376
# Epoch 3:     Train MAE: 22.45     Val MAE: 28.76     LR: 0.0001     Time: 0:44:32     Step: 11701/14376
# Epoch 3:     Train MAE: 23.72     Val MAE: 28.76     LR: 0.0001     Time: 0:44:55     Step: 11801/14376
# Epoch 3:     Train MAE: 24.06     Val MAE: 28.76     LR: 0.0001     Time: 0:45:18     Step: 11901/14376
# Epoch 3:     Train MAE: 22.85     Val MAE: 28.76     LR: 0.0001     Time: 0:45:41     Step: 12001/14376
# ...
# Epoch 9:     Train MAE: 22.30     Val MAE: 28.76     LR: 0.0001     Time: 0:48:50     Step: 12701/14376
# Epoch 9:     Train MAE: 21.37     Val MAE: 28.76     LR: 0.0001     Time: 0:49:13     Step: 12801/14376
# Epoch 9:     Train MAE: 24.11     Val MAE: 28.76     LR: 0.0001     Time: 0:49:36     Step: 12901/14376
# Epoch 9:     Train MAE: 22.19     Val MAE: 28.76     LR: 0.0001     Time: 0:49:59     Step: 13001/14376
# Epoch 9:     Train MAE: 22.39     Val MAE: 28.76     LR: 0.0001     Time: 0:50:22     Step: 13101/14376
# Epoch 9:     Train MAE: 23.84     Val MAE: 28.76     LR: 0.0001     Time: 0:50:44     Step: 13201/14376
# Epoch 9:     Train MAE: 23.78     Val MAE: 28.76     LR: 0.0001     Time: 0:51:07     Step: 13301/14376
# Epoch 9:     Train MAE: 23.54     Val MAE: 28.76     LR: 0.0001     Time: 0:51:30     Step: 13401/14376
# Epoch 9:     Train MAE: 26.19     Val MAE: 28.76     LR: 0.0001     Time: 0:51:54     Step: 13501/14376
# Epoch 9:     Train MAE: 26.42     Val MAE: 28.76     LR: 0.0001     Time: 0:52:17     Step: 13601/14376
# Epoch 9:     Train MAE: 26.26     Val MAE: 28.76     LR: 0.0001     Time: 0:52:40     Step: 13701/14376
# Epoch 9:     Train MAE: 22.45     Val MAE: 28.76     LR: 0.0001     Time: 0:53:03     Step: 13801/14376
# Epoch 9:     Train MAE: 23.75     Val MAE: 28.76     LR: 0.0001     Time: 0:53:26     Step: 13901/14376
# Epoch 9:     Train MAE: 23.79     Val MAE: 28.76     LR: 0.0001     Time: 0:53:49     Step: 14001/14376
# Epoch 9:     Train MAE: 24.20     Val MAE: 28.76     LR: 0.0001     Time: 0:54:12     Step: 14101/14376
# Epoch 9:     Train MAE: 23.09     Val MAE: 28.76     LR: 0.0001     Time: 0:54:35     Step: 14201/14376
# Epoch 9:     Train MAE: 24.38     Val MAE: 28.76     LR: 0.0001     Time: 0:54:58     Step: 14301/14376
# 100%|█████████████████████████████████████████| 313/313 [00:42<00:00,  7.43it/s]
# Saved weights latest..
# Epoch 10:     Train MAE: 23.91     Val MAE: 27.15     LR: 0.0001     Time: 0:00:08     Step: 1/14376
# Epoch 10:     Train MAE: 23.80     Val MAE: 27.15     LR: 0.0001     Time: 0:00:31     Step: 101/14376
# Epoch 10:     Train MAE: 23.22     Val MAE: 27.15     LR: 0.0001     Time: 0:00:53     Step: 201/14376
# Epoch 10:     Train MAE: 23.56     Val MAE: 27.15     LR: 0.0001     Time: 0:01:16     Step: 301/14376
# Epoch 10:     Train MAE: 24.85     Val MAE: 27.15     LR: 0.0001     Time: 0:01:39     Step: 401/14376
# Epoch 10:     Train MAE: 22.86     Val MAE: 27.15     LR: 0.0001     Time: 0:02:02     Step: 501/14376
# Epoch 10:     Train MAE: 23.90     Val MAE: 27.15     LR: 0.0001     Time: 0:02:24     Step: 601/14376
# Epoch 10:     Train MAE: 24.45     Val MAE: 27.15     LR: 0.0001     Time: 0:02:47     Step: 701/14376
# Epoch 10:     Train MAE: 24.31     Val MAE: 27.15     LR: 0.0001     Time: 0:03:10     Step: 801/14376
# Epoch 10:     Train MAE: 23.31     Val MAE: 27.15     LR: 0.0001     Time: 0:03:32     Step: 901/14376
# Epoch 10:     Train MAE: 23.92     Val MAE: 27.15     LR: 0.0001     Time: 0:03:55     Step: 1001/14376
# Epoch 10:     Train MAE: 23.60     Val MAE: 27.15     LR: 0.0001     Time: 0:04:18     Step: 1101/14376
# Epoch 10:     Train MAE: 24.09     Val MAE: 27.15     LR: 0.0001     Time: 0:04:40     Step: 1201/14376
# Epoch 10:     Train MAE: 23.81     Val MAE: 27.15     LR: 0.0001     Time: 0:05:03     Step: 1301/14376
# Epoch 10:     Train MAE: 23.22     Val MAE: 27.15     LR: 0.0001     Time: 0:05:26     Step: 1401/14376
# Epoch 10:     Train MAE: 28.42     Val MAE: 27.15     LR: 0.0001     Time: 0:05:49     Step: 1501/14376
# Epoch 10:     Train MAE: 24.62     Val MAE: 27.15     LR: 0.0001     Time: 0:06:12     Step: 1601/14376
# Epoch 10:     Train MAE: 22.37     Val MAE: 27.15     LR: 0.0001     Time: 0:06:35     Step: 1701/14376
# Epoch 10:     Train MAE: 23.40     Val MAE: 27.15     LR: 0.0001     Time: 0:06:58     Step: 1801/14376
# Epoch 10:     Train MAE: 24.84     Val MAE: 27.15     LR: 0.0001     Time: 0:07:21     Step: 1901/14376
# Epoch 10:     Train MAE: 25.01     Val MAE: 27.15     LR: 0.0001     Time: 0:07:44     Step: 2001/14376
# Epoch 10:     Train MAE: 22.10     Val MAE: 27.15     LR: 0.0001     Time: 0:08:07     Step: 2101/14376
# Epoch 10:     Train MAE: 22.43     Val MAE: 27.15     LR: 0.0001     Time: 0:08:30     Step: 2201/14376
# Epoch 10:     Train MAE: 24.97     Val MAE: 27.15     LR: 0.0001     Time: 0:08:54     Step: 2301/14376
# Epoch 10:     Train MAE: 22.96     Val MAE: 27.15     LR: 0.0001     Time: 0:09:17     Step: 2401/14376
# Epoch 10:     Train MAE: 24.87     Val MAE: 27.15     LR: 0.0001     Time: 0:09:39     Step: 2501/14376
# Epoch 10:     Train MAE: 24.36     Val MAE: 27.15     LR: 0.0001     Time: 0:10:02     Step: 2601/14376
# Epoch 10:     Train MAE: 23.66     Val MAE: 27.15     LR: 0.0001     Time: 0:10:25     Step: 2701/14376
# Epoch 10:     Train MAE: 22.62     Val MAE: 27.15     LR: 0.0001     Time: 0:10:48     Step: 2801/14376
# Epoch 10:     Train MAE: 22.88     Val MAE: 27.15     LR: 0.0001     Time: 0:11:11     Step: 2901/14376
# Epoch 10:     Train MAE: 24.83     Val MAE: 27.15     LR: 0.0001     Time: 0:11:34     Step: 3001/14376
# Epoch 10:     Train MAE: 23.15     Val MAE: 27.15     LR: 0.0001     Time: 0:11:57     Step: 3101/14376
# Epoch 10:     Train MAE: 21.41     Val MAE: 27.15     LR: 0.0001     Time: 0:12:20     Step: 3201/14376
# Epoch 10:     Train MAE: 24.56     Val MAE: 27.15     LR: 0.0001     Time: 0:12:43     Step: 3301/14376
# Epoch 10:     Train MAE: 24.87     Val MAE: 27.15     LR: 0.0001     Time: 0:13:06     Step: 3401/14376
# Epoch 10:     Train MAE: 24.22     Val MAE: 27.15     LR: 0.0001     Time: 0:13:28     Step: 3501/14376
# Epoch 10:     Train MAE: 25.27     Val MAE: 27.15     LR: 0.0001     Time: 0:13:52     Step: 3601/14376
# Epoch 10:     Train MAE: 23.32     Val MAE: 27.15     LR: 0.0001     Time: 0:14:14     Step: 3701/14376
# Epoch 10:     Train MAE: 24.63     Val MAE: 27.15     LR: 0.0001     Time: 0:14:37     Step: 3801/14376
# Epoch 10:     Train MAE: 24.41     Val MAE: 27.15     LR: 0.0001     Time: 0:15:00     Step: 3901/14376
# Epoch 10:     Train MAE: 23.22     Val MAE: 27.15     LR: 0.0001     Time: 0:15:23     Step: 4001/14376
# Epoch 10:     Train MAE: 22.79     Val MAE: 27.15     LR: 0.0001     Time: 0:15:46     Step: 4101/14376
# Epoch 10:     Train MAE: 25.63     Val MAE: 27.15     LR: 0.0001     Time: 0:16:09     Step: 4201/14376
# Epoch 10:     Train MAE: 26.83     Val MAE: 27.15     LR: 0.0001     Time: 0:16:33     Step: 4301/14376
# Epoch 10:     Train MAE: 22.46     Val MAE: 27.15     LR: 0.0001     Time: 0:16:56     Step: 4401/14376
# Epoch 10:     Train MAE: 22.90     Val MAE: 27.15     LR: 0.0001     Time: 0:17:19     Step: 4501/14376
# Epoch 10:     Train MAE: 23.52     Val MAE: 27.15     LR: 0.0001     Time: 0:17:42     Step: 4601/14376
# Epoch 10:     Train MAE: 22.81     Val MAE: 27.15     LR: 0.0001     Time: 0:18:04     Step: 4701/14376
# Epoch 10:     Train MAE: 24.47     Val MAE: 27.15     LR: 0.0001     Time: 0:18:27     Step: 4801/14376
# Epoch 10:     Train MAE: 23.92     Val MAE: 27.15     LR: 0.0001     Time: 0:18:50     Step: 4901/14376
# Epoch 10:     Train MAE: 23.11     Val MAE: 27.15     LR: 0.0001     Time: 0:19:13     Step: 5001/14376
# Epoch 10:     Train MAE: 24.39     Val MAE: 27.15     LR: 0.0001     Time: 0:19:35     Step: 5101/14376
# Epoch 10:     Train MAE: 23.51     Val MAE: 27.15     LR: 0.0001     Time: 0:19:58     Step: 5201/14376
# Epoch 10:     Train MAE: 24.91     Val MAE: 27.15     LR: 0.0001     Time: 0:20:20     Step: 5301/14376
# Epoch 10:     Train MAE: 25.48     Val MAE: 27.15     LR: 0.0001     Time: 0:20:43     Step: 5401/14376
# Epoch 10:     Train MAE: 24.01     Val MAE: 27.15     LR: 0.0001     Time: 0:21:06     Step: 5501/14376
# Epoch 10:     Train MAE: 24.02     Val MAE: 27.15     LR: 0.0001     Time: 0:21:29     Step: 5601/14376
# Epoch 10:     Train MAE: 24.50     Val MAE: 27.15     LR: 0.0001     Time: 0:21:51     Step: 5701/14376
# Epoch 10:     Train MAE: 24.25     Val MAE: 27.15     LR: 0.0001     Time: 0:22:14     Step: 5801/14376
# Epoch 10:     Train MAE: 24.83     Val MAE: 27.15     LR: 0.0001     Time: 0:22:36     Step: 5901/14376
# Epoch 10:     Train MAE: 25.22     Val MAE: 27.15     LR: 0.0001     Time: 0:22:59     Step: 6001/14376
# Epoch 10:     Train MAE: 23.98     Val MAE: 27.15     LR: 0.0001     Time: 0:23:21     Step: 6101/14376
# Epoch 10:     Train MAE: 23.85     Val MAE: 27.15     LR: 0.0001     Time: 0:23:44     Step: 6201/14376
# Epoch 10:     Train MAE: 25.17     Val MAE: 27.15     LR: 0.0001     Time: 0:24:07     Step: 6301/14376
# Epoch 10:     Train MAE: 24.96     Val MAE: 27.15     LR: 0.0001     Time: 0:24:29     Step: 6401/14376
# Epoch 10:     Train MAE: 22.48     Val MAE: 27.15     LR: 0.0001     Time: 0:24:52     Step: 6501/14376
# Epoch 10:     Train MAE: 22.79     Val MAE: 27.15     LR: 0.0001     Time: 0:25:15     Step: 6601/14376
# Epoch 10:     Train MAE: 27.87     Val MAE: 27.15     LR: 0.0001     Time: 0:25:38     Step: 6701/14376
# Epoch 10:     Train MAE: 24.91     Val MAE: 27.15     LR: 0.0001     Time: 0:26:01     Step: 6801/14376
# Epoch 10:     Train MAE: 24.39     Val MAE: 27.15     LR: 0.0001     Time: 0:26:25     Step: 6901/14376
# Epoch 10:     Train MAE: 23.13     Val MAE: 27.15     LR: 0.0001     Time: 0:26:48     Step: 7001/14376
# Epoch 10:     Train MAE: 24.47     Val MAE: 27.15     LR: 0.0001     Time: 0:27:11     Step: 7101/14376
# Epoch 10:     Train MAE: 25.12     Val MAE: 27.15     LR: 0.0001     Time: 0:27:34     Step: 7201/14376
# Epoch 10:     Train MAE: 24.03     Val MAE: 27.15     LR: 0.0001     Time: 0:27:56     Step: 7301/14376
# Epoch 10:     Train MAE: 26.53     Val MAE: 27.15     LR: 0.0001     Time: 0:28:19     Step: 7401/14376
# Epoch 10:     Train MAE: 29.13     Val MAE: 27.15     LR: 0.0001     Time: 0:28:43     Step: 7501/14376
# Epoch 10:     Train MAE: 31.38     Val MAE: 27.15     LR: 0.0001     Time: 0:29:06     Step: 7601/14376
# Epoch 10:     Train MAE: 28.39     Val MAE: 27.15     LR: 0.0001     Time: 0:29:29     Step: 7701/14376
# Epoch 10:     Train MAE: 28.63     Val MAE: 27.15     LR: 0.0001     Time: 0:29:52     Step: 7801/14376
# Epoch 10:     Train MAE: 26.90     Val MAE: 27.15     LR: 0.0001     Time: 0:30:15     Step: 7901/14376
# Epoch 10:     Train MAE: 26.03     Val MAE: 27.15     LR: 0.0001     Time: 0:30:37     Step: 8001/14376
# Epoch 10:     Train MAE: 26.03     Val MAE: 27.15     LR: 0.0001     Time: 0:31:01     Step: 8101/14376
# Epoch 10:     Train MAE: 25.96     Val MAE: 27.15     LR: 0.0001     Time: 0:31:24     Step: 8201/14376
# Epoch 10:     Train MAE: 24.77     Val MAE: 27.15     LR: 0.0001     Time: 0:31:46     Step: 8301/14376
# Epoch 10:     Train MAE: 24.13     Val MAE: 27.15     LR: 0.0001     Time: 0:32:09     Step: 8401/14376
# Epoch 10:     Train MAE: 22.95     Val MAE: 27.15     LR: 0.0001     Time: 0:32:32     Step: 8501/14376
# Epoch 10:     Train MAE: 24.87     Val MAE: 27.15     LR: 0.0001     Time: 0:32:55     Step: 8601/14376
# Epoch 10:     Train MAE: 25.90     Val MAE: 27.15     LR: 0.0001     Time: 0:33:19     Step: 8701/14376
# Epoch 10:     Train MAE: 24.47     Val MAE: 27.15     LR: 0.0001     Time: 0:33:42     Step: 8801/14376
# Epoch 10:     Train MAE: 23.43     Val MAE: 27.15     LR: 0.0001     Time: 0:34:05     Step: 8901/14376
# Epoch 10:     Train MAE: 23.32     Val MAE: 27.15     LR: 0.0001     Time: 0:34:27     Step: 9001/14376
# Epoch 10:     Train MAE: 23.97     Val MAE: 27.15     LR: 0.0001     Time: 0:34:50     Step: 9101/14376
# Epoch 10:     Train MAE: 24.36     Val MAE: 27.15     LR: 0.0001     Time: 0:35:13     Step: 9201/14376
# Epoch 10:     Train MAE: 24.24     Val MAE: 27.15     LR: 0.0001     Time: 0:35:36     Step: 9301/14376
# Epoch 10:     Train MAE: 24.68     Val MAE: 27.15     LR: 0.0001     Time: 0:35:59     Step: 9401/14376
# Epoch 10:     Train MAE: 24.18     Val MAE: 27.15     LR: 0.0001     Time: 0:36:21     Step: 9501/14376
# Epoch 10:     Train MAE: 25.75     Val MAE: 27.15     LR: 0.0001     Time: 0:36:44     Step: 9601/14376
# Epoch 10:     Train MAE: 24.46     Val MAE: 27.15     LR: 0.0001     Time: 0:37:07     Step: 9701/14376
# Epoch 10:     Train MAE: 23.68     Val MAE: 27.15     LR: 0.0001     Time: 0:37:29     Step: 9801/14376
# Epoch 10:     Train MAE: 24.57     Val MAE: 27.15     LR: 0.0001     Time: 0:37:52     Step: 9901/14376
# Epoch 10:     Train MAE: 25.78     Val MAE: 27.15     LR: 0.0001     Time: 0:38:15     Step: 10001/14376
# Epoch 10:     Train MAE: 24.65     Val MAE: 27.15     LR: 0.0001     Time: 0:38:38     Step: 10101/14376
# Epoch 10:     Train MAE: 23.39     Val MAE: 27.15     LR: 0.0001     Time: 0:39:00     Step: 10201/14376
# Epoch 10:     Train MAE: 26.07     Val MAE: 27.15     LR: 0.0001     Time: 0:39:24     Step: 10301/14376
# Epoch 10:     Train MAE: 22.92     Val MAE: 27.15     LR: 0.0001     Time: 0:39:46     Step: 10401/14376
# Epoch 10:     Train MAE: 23.50     Val MAE: 27.15     LR: 0.0001     Time: 0:40:09     Step: 10501/14376
# Epoch 10:     Train MAE: 22.03     Val MAE: 27.15     LR: 0.0001     Time: 0:40:32     Step: 10601/14376
# Epoch 10:     Train MAE: 25.04     Val MAE: 27.15     LR: 0.0001     Time: 0:40:56     Step: 10701/14376
# Epoch 10:     Train MAE: 23.83     Val MAE: 27.15     LR: 0.0001     Time: 0:41:18     Step: 10801/14376
# Epoch 10:     Train MAE: 24.21     Val MAE: 27.15     LR: 0.0001     Time: 0:41:41     Step: 10901/14376
# Epoch 10:     Train MAE: 23.97     Val MAE: 27.15     LR: 0.0001     Time: 0:42:04     Step: 11001/14376
# Epoch 10:     Train MAE: 23.57     Val MAE: 27.15     LR: 0.0001     Time: 0:42:27     Step: 11101/14376
# Epoch 10:     Train MAE: 23.17     Val MAE: 27.15     LR: 0.0001     Time: 0:42:50     Step: 11201/14376
# Epoch 10:     Train MAE: 23.70     Val MAE: 27.15     LR: 0.0001     Time: 0:43:13     Step: 11301/14376
# Epoch 10:     Train MAE: 23.63     Val MAE: 27.15     LR: 0.0001     Time: 0:43:36     Step: 11401/14376
# Epoch 10:     Train MAE: 24.69     Val MAE: 27.15     LR: 0.0001     Time: 0:43:59     Step: 11501/14376
# Epoch 10:     Train MAE: 24.80     Val MAE: 27.15     LR: 0.0001     Time: 0:44:22     Step: 11601/14376
# Epoch 10:     Train MAE: 26.19     Val MAE: 27.15     LR: 0.0001     Time: 0:44:45     Step: 11701/14376
# Epoch 10:     Train MAE: 25.11     Val MAE: 27.15     LR: 0.0001     Time: 0:45:07     Step: 11801/14376
# Epoch 10:     Train MAE: 24.18     Val MAE: 27.15     LR: 0.0001     Time: 0:45:30     Step: 11901/14376
# Epoch 10:     Train MAE: 24.90     Val MAE: 27.15     LR: 0.0001     Time: 0:45:53     Step: 12001/14376
# Epoch 10:     Train MAE: 24.62     Val MAE: 27.15     LR: 0.0001     Time: 0:46:15     Step: 12101/14376
# Epoch 10:     Train MAE: 25.04     Val MAE: 27.15     LR: 0.0001     Time: 0:46:38     Step: 12201/14376
# Epoch 10:     Train MAE: 23.92     Val MAE: 27.15     LR: 0.0001     Time: 0:47:01     Step: 12301/14376
# Epoch 10:     Train MAE: 22.17     Val MAE: 27.15     LR: 0.0001     Time: 0:47:24     Step: 12401/14376
# Epoch 10:     Train MAE: 22.71     Val MAE: 27.15     LR: 0.0001     Time: 0:47:46     Step: 12501/14376
# Epoch 10:     Train MAE: 25.02     Val MAE: 27.15     LR: 0.0001     Time: 0:48:09     Step: 12601/14376
# Epoch 10:     Train MAE: 24.92     Val MAE: 27.15     LR: 0.0001     Time: 0:48:32     Step: 12701/14376
# Epoch 10:     Train MAE: 22.80     Val MAE: 27.15     LR: 0.0001     Time: 0:48:55     Step: 12801/14376
# Epoch 10:     Train MAE: 23.41     Val MAE: 27.15     LR: 0.0001     Time: 0:49:18     Step: 12901/14376
# Epoch 10:     Train MAE: 24.10     Val MAE: 27.15     LR: 0.0001     Time: 0:49:40     Step: 13001/14376
# Epoch 10:     Train MAE: 24.12     Val MAE: 27.15     LR: 0.0001     Time: 0:50:03     Step: 13101/14376
# Epoch 10:     Train MAE: 23.57     Val MAE: 27.15     LR: 0.0001     Time: 0:50:25     Step: 13201/14376
# Epoch 10:     Train MAE: 25.10     Val MAE: 27.15     LR: 0.0001     Time: 0:50:49     Step: 13301/14376
# Epoch 10:     Train MAE: 25.20     Val MAE: 27.15     LR: 0.0001     Time: 0:51:11     Step: 13401/14376

# %% [markdown]
# ### Pretrained Model
#
# Next, we load in the pretrained model. This model was trained with a batch size of 16 for 200 epochs.

# %%
import glob

import torch
import torch.nn as nn
import torch.nn.functional as F

from _cfg import cfg

if RUN_VALID or RUN_TEST:

    # Load pretrained models
    models = []
    for f in sorted(glob.glob("/kaggle/input/gwi-cycle6/best_model_123.pt")):
        print("Loading: ", f)
        m = Net(
            backbone=cfg.backbone,
            pretrained=False,
        )
        state_dict= torch.load(f, map_location=cfg.device, weights_only=True)
        state_dict= {k.removeprefix("_orig_mod."):v for k,v in state_dict.items()} # Remove torch.compile() prefix

        m.load_state_dict(state_dict)
        models.append(m)

    # Combine
    model = EnsembleModel(models)
    model = model.to(cfg.device)
    model = model.eval()
    print("n_models: {:_}".format(len(models)))

# %% [markdown]
# # Valid
#
# Next, we score the ensemble on the validation set.

# %%
from tqdm import tqdm
import numpy as np

import torch
import torch.nn as nn
from torch.amp import autocast

from _dataset import CustomDataset


if RUN_VALID:

    # Dataset / Dataloader
    valid_ds = CustomDataset(cfg=cfg, mode="valid")
    sampler = torch.utils.data.SequentialSampler(valid_ds)
    valid_dl = torch.utils.data.DataLoader(
        valid_ds,
        sampler= sampler,
        batch_size= cfg.batch_size_val,
        num_workers= 4,
    )

    # Valid loop
    criterion = nn.L1Loss()
    val_logits = []
    val_targets = []

    with torch.no_grad():
        for x, y in tqdm(valid_dl):
            x = x.to(cfg.device)
            y = y.to(cfg.device)

            with autocast(cfg.device.type):
                out = model(x)

            val_logits.append(out.cpu())
            val_targets.append(y.cpu())

        val_logits= torch.cat(val_logits, dim=0)
        val_targets= torch.cat(val_targets, dim=0)

        total_loss= criterion(val_logits, val_targets).item()

    # Dataset Scores
    ds_idxs= np.array([valid_ds.records])
    ds_idxs= np.repeat(ds_idxs, repeats=500)

    print("="*25)
    with torch.no_grad():
        for idx in sorted(np.unique(ds_idxs)):

            # Mask
            mask = ds_idxs == idx
            logits_ds = val_logits[mask]
            targets_ds = val_targets[mask]

            # Score predictions
            loss = criterion(val_logits[mask], val_targets[mask]).item()
            print("{:15} {:.2f}".format(idx, loss))
    print("="*25)
    print("Val MAE: {:.2f}".format(total_loss))
    print("="*25)

# %% [markdown]
# # Test
#
# Finally, we make predictions on the test data.

# %%
import torch

class TestDataset(torch.utils.data.Dataset):
    def __init__(self, test_files):
        self.test_files = test_files

    def __len__(self):
        return len(self.test_files)

    def __getitem__(self, i):
        test_file = self.test_files[i]
        test_stem = test_file.split("/")[-1].split(".")[0]
        return np.load(test_file), test_stem

# %%
import csv
import time
import glob
from tqdm import tqdm
import numpy as np
import pandas as pd


if RUN_TEST:

    ss= pd.read_csv("/kaggle/input/waveform-inversion/sample_submission.csv")
    row_count = 0
    t0 = time.time()

    test_files = sorted(glob.glob("/kaggle/input/open-wfi-test/test/*.npy"))
    x_cols = [f"x_{i}" for i in range(1, 70, 2)]
    fieldnames = ["oid_ypos"] + x_cols

    test_ds = TestDataset(test_files)
    test_dl = torch.utils.data.DataLoader(
        test_ds,
        sampler=torch.utils.data.SequentialSampler(test_ds),
        batch_size=cfg.batch_size_val,
        num_workers=4,
    )

    with open("submission.csv", "wt", newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        with torch.inference_mode():
            with torch.autocast(cfg.device.type):
                for inputs, oids_test in tqdm(test_dl, total=len(test_dl)):
                    inputs = inputs.to(cfg.device)

                    outputs = model(inputs)

                    y_preds = outputs[:, 0].cpu().numpy()

                    for y_pred, oid_test in zip(y_preds, oids_test):
                        for y_pos in range(70):
                            row = dict(zip(x_cols, [y_pred[y_pos, x_pos] for x_pos in range(1, 70, 2)]))
                            row["oid_ypos"] = f"{oid_test}_y_{y_pos}"

                            writer.writerow(row)
                            row_count += 1

                            # Clear buffer
                            if row_count % 100_000 == 0:
                                csvfile.flush()

    #t1 = format_time(time.time() - t0)
    #print(f"Inference Time: {t1}")

# %% [markdown]
# We can also view a few samples to make sure things look reasonable.

# %%
import matplotlib.pyplot as plt

if RUN_TEST:
    # Plot a few samples
    fig, axes = plt.subplots(3, 5, figsize=(10, 6))
    axes= axes.flatten()

    n = min(len(outputs), len(axes))

    for i in range(n):
        img= outputs[0, 0, ...].cpu().numpy()
        img = outputs[i, 0].cpu().numpy()
        idx= oids_test[i]

        # Plot
        axes[i].imshow(img, cmap='gray')
        axes[i].set_title(idx)
        axes[i].axis('off')

    for i in range(n, len(axes)):
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()
